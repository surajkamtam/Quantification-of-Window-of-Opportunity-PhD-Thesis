# %%
import numpy as np
from tensorflow.keras.optimizers import Adam
import matplotlib.pyplot as plt
from scipy.spatial.distance import cdist
import os
import pandas as pd
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import (Input, Conv1D, MaxPooling1D, 
                                     LSTM, Bidirectional, Dense, 
                                     Reshape, Dropout, Attention, 
                                     Concatenate, LayerNormalization)
# from tensorflow.keras.optimizers import Adam
from tensorflow.keras import backend as K
from sklearn.model_selection import train_test_split
from sklearn.metrics import (precision_score, recall_score, 
                             f1_score, confusion_matrix)
# import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow.keras.layers import GRU  # Add GRU import
from sklearn.metrics import mean_squared_error



def build_prediction_model(input_shape, output_steps, n_features):
    inputs = Input(shape=input_shape)

    x = Conv1D(filters=64, kernel_size=3, activation='relu', padding='same')(inputs)
    x = MaxPooling1D(pool_size=2)(x)
    x = Bidirectional(GRU(64, return_sequences=True))(x)

    attention = Attention()([x, x])  # Self-attention
    x = Concatenate()([x, attention])
    x = LayerNormalization()(x)
    x = Dropout(0.1)(x)

    x = GRU(64)(x)
    x = Dense(64, activation='relu')(x)
    x = Dense(output_steps * n_features)(x)
    outputs = Reshape((output_steps, n_features))(x)

    model = Model(inputs, outputs)
    model.compile(optimizer=Adam(learning_rate=0.00093286), loss='mse', metrics=['mae', f1])
    return model

def load_trained_model(input_shape, output_steps, n_features):
    model = build_prediction_model(input_shape, output_steps, n_features)
    model.load_weights("gru_epoch_100_10_5.weights.h5")
    return model


def f1(y_true, y_pred):
    def recall(y_true, y_pred):
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
        return true_positives / (possible_positives + K.epsilon())

    def precision(y_true, y_pred):
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
        return true_positives / (predicted_positives + K.epsilon())

    p = precision(y_true, y_pred)
    r = recall(y_true, y_pred)
    return 2 * ((p * r) / (p + r + K.epsilon()))


def calculate_entropy(data):
    value_counts = np.bincount(data)
    probabilities = value_counts / np.sum(value_counts)
    probabilities = probabilities[probabilities > 0]
    return -np.sum(probabilities * np.log2(probabilities))


def dynthreshold(vectime, vecvalue):
    time_stamps = np.array(vectime)
    packets = np.array(vecvalue)
    packets_int = np.round(packets).astype(int)
    num_points = len(packets_int)

    window_size = 15
    entropy_values = np.array([
        calculate_entropy(packets_int[max(0, i - window_size):i + 1]) for i in range(num_points)
    ])
    H_avg = np.mean(entropy_values)
    sigma = np.std(entropy_values)
    a = 0.2
    T_1 = H_avg + a * sigma
    return entropy_values, T_1, H_avg


def hausdorff_distance(set1, set2):
    dists = cdist(set1, set2, metric='euclidean')
    forward = np.max(np.min(dists, axis=1))
    backward = np.max(np.min(dists, axis=0))
    return max(forward, backward)



def plot_residuals(prediction, actual_continuation, feature_names, test_labels, time_sequence, look_back=18):
    if actual_continuation is None:
        print("Actual continuation is not available, cannot compute residuals.")
        return

    def compute_ewma(series, alpha=0.2):
        ewma = np.zeros_like(series)
        ewma[0] = series[0]
        for t in range(1, len(series)):
            ewma[t] = alpha * series[t] + (1 - alpha) * ewma[t - 1]
        return ewma

    def rmse_windowed(y_true, y_pred, window):
        return np.sqrt(np.mean((y_true - y_pred) ** 2, axis=1))

    plot_times = time_sequence[look_back:look_back + len(prediction)]
    plt.figure(figsize=(15, 6))

    for i, feature in enumerate(feature_names):
        plt.subplot(len(feature_names), 2, 2 * i + 1)

        window_size = 5
        rmse_series = np.array([
            np.mean((actual_continuation[t:t+window_size, i] - prediction[t:t+window_size, i]) ** 2)
            if t + window_size <= len(prediction) else 0
            for t in range(len(prediction))
        ])

        smoothed_rmse = compute_ewma(rmse_series)
        entropy_vals, T1, H_avg = dynthreshold(plot_times, smoothed_rmse)
        anomalies = (entropy_vals > T1).astype(int)

        for idx in np.where(anomalies == 1)[0]:
            plt.axvspan(plot_times[idx] - 0.5, plot_times[idx] + 0.5, color='red', alpha=0.2)

        true_anomalies_idx = np.where(test_labels[look_back:look_back + len(prediction)] == 1)[0]
        for idx in true_anomalies_idx:
            plt.axvspan(plot_times[idx] - 0.5, plot_times[idx] + 0.5, color='yellow', alpha=0.2)

        y_true = test_labels[look_back:look_back + len(prediction)]
        y_pred = anomalies

        TP = np.sum((y_pred == 1) & (y_true == 1))
        FN = np.sum((y_pred == 0) & (y_true == 1))
        FP = np.sum((y_pred == 1) & (y_true == 0))
        TN = np.sum((y_pred == 0) & (y_true == 0))

        prob_detection = (TP / (TP + FN)) * 100 if (TP + FN) > 0 else 0.0
        false_alarm_rate = (FP / (FP + TN)) * 100 if (FP + TN) > 0 else 0.0

        print(f"\nMetrics for Feature: {feature}")
        print(f"True Positives: {TP}")
        print(f"False Positives: {FP}")
        print(f"False Negatives: {FN}")
        print(f"True Negatives: {TN}")
        print(f"Probability of Detection (PD): {prob_detection:.2f}%")
        print(f"False Alarm Rate (FAR): {false_alarm_rate:.2f}%")

        num_anomalies = np.sum(y_pred == 1)
        total_points = len(y_pred)
        anomaly_probability = (num_anomalies / total_points) if total_points > 0 else 0.0

        print(f"Anomaly Prob: {num_anomalies}/{total_points} ({anomaly_probability:.2f})")

        plt.plot(plot_times, rmse_series, label='MSE', color='blue', linestyle='dotted', alpha=0.5)
        plt.plot(plot_times, smoothed_rmse, label='EWMA(MSE)', color='blue')
        # plt.title(f'{feature} RMSE & EWMA - Anomaly Prob = {anomaly_probability:.2f}')
        import matplotlib.patches as mpatches
        pred_patch = mpatches.Patch(color='red', alpha=0.2, label='Predicted Anomalies')
        true_patch = mpatches.Patch(color='yellow', alpha=0.2, label='True Anomalies')
        plt.xlabel('Time')
        plt.ylabel('Error')
        # plt.legend()
        plt.legend(handles=[pred_patch, true_patch] + plt.gca().get_legend_handles_labels()[0])

        plt.grid(True)

        plt.subplot(len(feature_names), 2, 2 * i + 2)
        plt.plot(plot_times, entropy_vals, label='Entropy', color='blue')
        plt.axhline(y=T1, color='black', linestyle='--', label=f'Threshold = {T1:.2f}')
        # plt.axhline(y=H_avg, color='green', linestyle=':', label=f'H_avg = {H_avg:.2f}')
        # plt.title(f'{feature} Entropy of EWMA(RMSE)')
        plt.xlabel('Time')
        plt.ylabel('Entropy')
        plt.legend()
        plt.grid(True)

    plt.tight_layout()
    plt.savefig('residuals_rmse_entropy_anomalies.png')
    plt.show()



def test_single_sequence(model, input_sequence):
    input_seq = np.expand_dims(input_sequence, axis=0)
    prediction = model.predict(input_seq)[0]
    return prediction


def plot_test_results(input_sequence, prediction, actual_continuation, labels, feature_names, time_sequence):
    look_back = input_sequence.shape[0]
    look_forward = prediction.shape[0]
    full_times = time_sequence[:look_back + look_forward]

    plt.figure(figsize=(15, 6))

    for i, feature in enumerate(feature_names):
        plt.subplot(1, len(feature_names), i+1)

        plt.plot(full_times[:look_back], input_sequence[:, i], 'b-o', label='Input')
        plt.plot(full_times[look_back:look_back + look_forward], prediction[:, i], 'r--o', label='Prediction')

        if actual_continuation is not None:
            plt.plot(full_times[look_back:look_back + look_forward], actual_continuation[:, i], 'g-o', label='Actual')

        input_anomalies = np.where(labels[:look_back] == 1)[0]
        for idx in input_anomalies:
            plt.axvspan(full_times[idx] - 0.5, full_times[idx] + 0.5, color='red', alpha=0.2)

        continuation_anomalies = np.where(labels[look_back:look_back + look_forward] == 1)[0]
        for idx in continuation_anomalies:
            plt.axvspan(full_times[look_back + idx] - 0.5, full_times[look_back + idx] + 0.5, color='red', alpha=0.2)

        plt.title(f'{feature} Prediction vs Actual')
        plt.xlabel('Time')
        plt.ylabel('Value')
        plt.legend()
        plt.grid(True)

    plt.tight_layout()
    plt.savefig('prediction_vs_actual.png')
    plt.show()

def rolling_rmse(actual, predicted, window_size):
    rmse = np.full_like(actual, np.nan, dtype=np.float64)
    for i in range(window_size - 1, len(actual)):
        rmse[i] = (mean_squared_error(actual[i - window_size + 1:i + 1],
                                             predicted[i - window_size + 1:i + 1]))
    return rmse

def plot_overlay_with_rmse_residuals(time, actual, predicted, feature_name="Feature", rmse_window=10, prediction_window=10):
    residual_rmse = rolling_rmse(actual, predicted, rmse_window)

    fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(12, 8), sharex=True,
                                   gridspec_kw={'height_ratios': [3, 1]})

    # Plot Actual and Predicted
    ax1.plot(time, actual, label='Actual', color='green', linewidth=2)
    ax1.plot(time, predicted, label='Predicted', color='red',linestyle='dotted', alpha=0.7, linewidth=2)

    # Shade prediction windows (gray)
    for start in range(0, len(time), prediction_window):
        end = min(start + prediction_window, len(time))
        ax1.axvspan(time[start], time[end - 1], color='gray', alpha=0.1)

    # Shade RMSE windows (light blue)
    for start in range(rmse_window - 1, len(time), rmse_window):
        end = min(start + 1, len(time))  # Single point RMSE computed at this time
        ax2.axvspan(time[start - rmse_window + 1], time[start], color='lightblue', alpha=0.2)

    ax1.set_ylabel("Value")
    ax1.legend()

    # Plot RMSE Residual
    ax2.plot(time, residual_rmse, label=f'Rolling MSE', color='blue', linestyle='--', linewidth=2)
    ax2.set_xlabel("Time")
    ax2.set_ylabel("MSE")
    ax2.legend()

    # Remove all borders and grid
    for ax in [ax1, ax2]:
        for spine in ax.spines.values():
            spine.set_visible(False)
        ax.tick_params(top=False, right=False)
        ax.grid(False)

    plt.tight_layout()
    plt.savefig('overlay_with_rmse_and_prediction_windows.png')
    plt.show()


# ---------------------- MAIN ----------------------
if __name__ == "__main__":
    # Load the CSV
    df = pd.read_csv('All_LOS_DATA_decel_sequence_data_with_jerk.csv')

    # Filter sequence if needed (e.g., LOS, DepartureTime, Iteration)
    seq_df = df[(df['LOS'] == 'E') & (df['DepartureTime'] == 905) & (df['Iteration'] == 17)]  # <-- apply filters if necessary

    # Extract features, labels, and time
    time_sequence = seq_df['Time'].values
    full_features = seq_df[['Speed','Acceleration','Jerk']].values
    full_labels = seq_df['Label'].values.astype(int)
    feature_names = ['Jerk'] #['Speed','Acceleration','Jerk']

    # Verify shape consistency
    if full_features.shape[1] != 3:
        raise ValueError(f"Expected 3 features, got {full_features.shape[1]}. Ensure you're using ['Speed', 'Acceleration', 'Jerk'].")

    # Parameters
    look_back = 10
    look_forward = 5
    n_features = 3

    model = load_trained_model(
        input_shape=(look_back, n_features),
        output_steps=look_forward,
        n_features=n_features
    )

    # Initialize variables for storing predictions
    all_predictions = []
    all_actuals = []
    all_times = []

    # Loop through the sequence with sliding window
    for i in range(0, len(full_features) - look_back - look_forward + 1, look_forward):
        # Get current window
        current_window = full_features[i:i+look_back]
        actual_continuation = full_features[i+look_back:i+look_back+look_forward]
        time_window = time_sequence[i+look_back:i+look_back+look_forward]
        
        # Make prediction
        prediction = test_single_sequence(model, current_window)
        
        # Store results
        all_predictions.append(prediction)
        all_actuals.append(actual_continuation)
        all_times.append(time_window)

    # Convert lists to numpy arrays
    all_predictions = np.concatenate(all_predictions)
    all_actuals = np.concatenate(all_actuals)
    all_times = np.concatenate(all_times)

    # Create full predicted sequence (initial input + predictions)
    predicted_sequence = np.vstack([full_features[:look_back], all_predictions])
    actual_sequence = np.vstack([full_features[:look_back], all_actuals])
    time_plot = np.concatenate([time_sequence[:look_back], all_times])

    # ---- Plotting ----
    plt.figure(figsize=(18, 6))

    for i, feature in enumerate(feature_names):
        plt.subplot(1, len(feature_names), i + 1)
        
        plt.plot(time_plot[:look_back], predicted_sequence[:look_back, i], 'b-o', label='Input', alpha=0.6)
        plt.plot(time_plot[look_back:], predicted_sequence[look_back:, i], 'r--', label='Predicted')
        plt.plot(time_plot[look_back:], actual_sequence[look_back:, i], 'g-', label='Actual')
        
        # Mark prediction windows
        for j in range(look_back, len(time_plot), look_forward):
            end = min(j + look_forward, len(time_plot))
            plt.axvspan(time_plot[j], time_plot[end-1], color='gray', alpha=0.1)
        
        # plt.title(f'{feature}: Prediction vs Actual (Window size: {look_back}→{look_forward})')
        plt.xlabel('Time')
        plt.ylabel('Value')
        plt.grid(True)
        plt.legend()

    plt.tight_layout()
    plt.savefig('windowed_prediction_vs_actual.png')
    plt.show()

    # Slice matching labels
    test_labels = full_labels[:predicted_sequence.shape[0]]

    # Plot anomaly detection and print metrics
    plot_residuals(
        prediction=predicted_sequence[look_back:], 
        actual_continuation=actual_sequence[look_back:], 
        feature_names=feature_names,
        test_labels=test_labels,
        time_sequence=time_plot,
        look_back=look_back
    )

    # Plot overlay with RMSE for each feature
    for i, feature_name in enumerate(feature_names):
        plot_overlay_with_rmse_residuals(
            time=time_plot[look_back:], 
            actual=actual_sequence[look_back:, i], 
            predicted=predicted_sequence[look_back:, i],
            feature_name=feature_name,
            rmse_window=10,
            prediction_window=look_forward
        )
# Out:
# /var/data/python/lib/python3.12/site-packages/keras/src/saving/saving_lib.py:757: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 36 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 293ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Metrics for Feature: Jerk
# True Positives: 21
# False Positives: 8
# False Negatives: 0
# True Negatives: 211
# Probability of Detection (PD): 100.00%
# False Alarm Rate (FAR): 3.65%
# Anomaly Prob: 29/240 (0.12)

# %% [markdown]
# # Test for Each LOS

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import time
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv1D, MaxPooling1D, LSTM, Bidirectional, Dense, Reshape, Dropout, Attention, Concatenate, LayerNormalization, GRU
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import backend as K
from sklearn.metrics import confusion_matrix, roc_auc_score, f1_score
from scipy.spatial.distance import cdist

# ---------------------- Model Definition ----------------------

def f1(y_true, y_pred):
    def recall(y_true, y_pred):
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
        return true_positives / (possible_positives + K.epsilon())

    def precision(y_true, y_pred):
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
        return true_positives / (predicted_positives + K.epsilon())

    p = precision(y_true, y_pred)
    r = recall(y_true, y_pred)
    return 2 * ((p * r) / (p + r + K.epsilon()))

def build_prediction_model(input_shape, output_steps, n_features):
    inputs = Input(shape=input_shape)

    x = Conv1D(filters=64, kernel_size=3, activation='relu', padding='same')(inputs)
    x = MaxPooling1D(pool_size=2)(x)
    x = Bidirectional(GRU(64, return_sequences=True))(x)

    attention = Attention()([x, x])  # Self-attention
    x = Concatenate()([x, attention])
    x = LayerNormalization()(x)
    x = Dropout(0.1)(x)

    x = GRU(64)(x)
    x = Dense(64, activation='relu')(x)
    x = Dense(output_steps * n_features)(x)
    outputs = Reshape((output_steps, n_features))(x)

    model = Model(inputs, outputs)
    model.compile(optimizer=Adam(learning_rate=0.00093286), loss='mse', metrics=['mae', f1])
    return model

def load_trained_model(input_shape, output_steps, n_features):
    model = build_prediction_model(input_shape, output_steps, n_features)
    model.load_weights("gru_epoch_100_10_5.weights.h5")
    return model

# ---------------------- Helper Functions ----------------------

def calculate_entropy(data):
    value_counts = np.bincount(data)
    probabilities = value_counts / np.sum(value_counts)
    probabilities = probabilities[probabilities > 0]
    return -np.sum(probabilities * np.log2(probabilities))

def dynthreshold(vectime, vecvalue):
    packets_int = np.round(vecvalue).astype(int)
    num_points = len(packets_int)
    window_size = 15
    entropy_values = np.array([
        calculate_entropy(packets_int[max(0, i - window_size):i + 1]) for i in range(num_points)
    ])
    H_avg = np.mean(entropy_values)
    sigma = np.std(entropy_values)
    a = 0.2
    T_1 = H_avg + a * sigma
    return entropy_values, T_1, H_avg

def test_single_sequence(model, input_sequence):
    input_seq = np.expand_dims(input_sequence, axis=0)
    prediction = model.predict(input_seq)[0]
    return prediction

def compute_ewma(series, alpha=0.2):
        ewma = np.zeros_like(series)
        ewma[0] = series[0]
        for t in range(1, len(series)):
            ewma[t] = alpha * series[t] + (1 - alpha) * ewma[t - 1]
        return ewma

# ---------------------- Main Processing ----------------------

if __name__ == "__main__":
    df = pd.read_csv('Persistent_losA_Decel_sequence_data_with_jerk.csv')

    look_back = 10
    look_forward = 5
    n_features = 3
    feature_names = ['Speed', 'Acceleration', 'Jerk']
    target_feature = 'Jerk'

    model = load_trained_model(
        input_shape=(look_back, n_features),
        output_steps=look_forward,
        n_features=n_features
    )

    sequences = df[['LOS', 'DepartureTime', 'Iteration']].drop_duplicates()
    metrics_summary = []

    for idx, row in sequences.iterrows():
        start_time = time.time()

        los = row['LOS']
        departure_time = row['DepartureTime']
        iteration = row['Iteration']
        print(los, departure_time, iteration)
        seq_df = df[(df['LOS'] == los) & (df['DepartureTime'] == departure_time) & (df['Iteration'] == iteration)]
        if len(seq_df) < (look_back + look_forward):
            continue

        time_sequence = seq_df['Time'].values
        full_features = seq_df[['Speed', 'Acceleration', 'Jerk']].values
        full_labels = seq_df['Label'].values.astype(int)

        all_predictions, all_actuals, all_times, all_labels = [], [], [], []

        for i in range(0, len(full_features) - look_back - look_forward + 1, look_forward):
            current_window = full_features[i:i+look_back]
            actual_continuation = full_features[i+look_back:i+look_back+look_forward]
            time_window = time_sequence[i+look_back:i+look_back+look_forward]
            label_window = full_labels[i+look_back:i+look_back+look_forward]
            prediction = test_single_sequence(model, current_window)
            all_predictions.append(prediction)
            all_actuals.append(actual_continuation)
            all_times.append(time_window)
            all_labels.append(label_window)

        if not all_predictions:
            continue

        all_predictions = np.concatenate(all_predictions)
        all_actuals = np.concatenate(all_actuals)
        all_times = np.concatenate(all_times)
        all_labels = np.concatenate(all_labels)

        predicted_sequence = np.vstack([full_features[:look_back], all_predictions])
        actual_sequence = np.vstack([full_features[:look_back], all_actuals])
        time_plot = np.concatenate([time_sequence[:look_back], all_times])
        test_labels = np.concatenate([full_labels[:look_back], all_labels])

        feature_idx = feature_names.index(target_feature)
        window_size = 10
        mse_series = np.array([
            np.mean((actual_sequence[t:t+window_size, feature_idx] - predicted_sequence[t:t+window_size, feature_idx]) ** 2)
            if t + window_size <= len(predicted_sequence) else 0
            for t in range(len(predicted_sequence))
        ])

        smoothed_mse = compute_ewma(mse_series[look_back:])
        entropy_vals, T1, H_avg = dynthreshold(time_plot[look_back:], smoothed_mse)
        anomalies = (entropy_vals > T1).astype(int)

        y_true = test_labels[look_back:look_back+len(smoothed_mse)]
        y_pred = anomalies

        TP = np.sum((y_pred == 1) & (y_true == 1))
        FP = np.sum((y_pred == 1) & (y_true == 0))
        FN = np.sum((y_pred == 0) & (y_true == 1))
        TN = np.sum((y_pred == 0) & (y_true == 0))

        try:
            auc = roc_auc_score(y_true, entropy_vals)
        except ValueError:
            auc = np.nan

        f1_val = f1_score(y_true, y_pred, zero_division=0)
        prob_detection = (TP / (TP + FN)) * 100 if (TP + FN) > 0 else 0.0
        false_alarm_rate = (FP / (FP + TN)) * 100 if (FP + TN) > 0 else 0.0
        anomaly_probability = (np.sum(y_pred == 1) / len(y_pred)) if len(y_pred) > 0 else 0.0

        end_time = time.time()

        metrics_summary.append({
            'LOS': los,
            'DepartureTime': departure_time,
            'Iteration': iteration,
            'TP': TP,
            'FP': FP,
            'FN': FN,
            'TN': TN,
            'PD': prob_detection,
            'FAR': false_alarm_rate,
            'F1': f1_val,
            'AUC': auc,
            'Anomaly_Prob': anomaly_probability,
            'Time_sec': end_time - start_time
        })

    if metrics_summary:
        metrics_df = pd.DataFrame(metrics_summary)
        numeric_cols = metrics_df.select_dtypes(include=np.number).columns
        median_metrics = metrics_df[numeric_cols].median()
        mean_metrics = metrics_df[numeric_cols].mean()

        print(f"\n=== Summary Metrics for Feature: {target_feature} ===")
        print(f"Window Configuration: look_back={look_back}, look_forward={look_forward}")
        print(f"Total sequences analyzed: {len(metrics_df)}")

        print("\nMedian Metrics:")
        print(median_metrics.round(4))

        print("\nMean Metrics:")
        print(mean_metrics.round(4))
    else:
        print(f"No metrics collected for feature: {target_feature}")
# Out:
# /var/data/python/lib/python3.12/site-packages/keras/src/saving/saving_lib.py:757: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 36 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# A 895 1
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 327ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# A 895 2
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# A 895 3
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# A 895 4
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# A 895 5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# A 895 6
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# A 895 7
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# A 895 8
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# A 895 9
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# A 895 10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# A 895 11
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# A 895 12
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# A 895 13
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# A 895 14
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# A 895 15
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# A 895 16
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# A 895 17
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# A 895 18
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# A 895 19
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# A 895 20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# A 895 21
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# /var/data/python/lib/python3.12/site-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# A 895 22
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# A 895 23
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# A 895 24
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# A 895 25
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# A 895 26
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# A 895 27
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# A 895 28
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# A 895 29
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# A 895 30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# A 896 1
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# A 896 2
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# A 896 3
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# A 896 4
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# A 896 5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# A 896 6
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# A 896 7
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# A 896 8
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# A 896 9
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# A 896 10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# A 896 11
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# A 896 12
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# A 896 13
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# A 896 14
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# A 896 15
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# A 896 16
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# A 896 17
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# A 896 18
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# A 896 19
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# A 896 20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# A 896 21
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# A 896 22
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# A 896 23
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# A 896 24
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# A 896 25
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# A 896 26
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# A 896 27
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# A 896 28
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# A 896 29
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# A 896 30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# A 897 1
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# A 897 2
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# A 897 3
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# A 897 4
# ...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# A 905 10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# A 905 11
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# A 905 12
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# A 905 13
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# A 905 14
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# A 905 15
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# A 905 16
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# A 905 17
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# A 905 18
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# A 905 19
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# A 905 20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# A 905 21
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# A 905 22
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# A 905 23
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# A 905 24
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# A 905 25
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# A 905 26
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# A 905 27
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# A 905 28
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# A 905 29
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# A 905 30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
#
# === Summary Metrics for Feature: Jerk ===
# Window Configuration: look_back=10, look_forward=5
# Total sequences analyzed: 330
#
# Median Metrics:
# DepartureTime    900.0000
# Iteration         15.5000
# TP                20.0000
# FP                12.5000
# FN                 1.0000
# TN                63.0000
# PD                95.2381
# FAR               15.0949
# F1                 0.6891
# AUC                0.9113
# Anomaly_Prob       0.3053
# Time_sec           1.6029
# dtype: float64
#
# Mean Metrics:
# DepartureTime    900.0000
# Iteration         15.5000
# TP                16.9364
# FP                12.9576
# FN                 3.9061
# TN                64.1545
# PD                80.7843
# FAR               16.8976
# F1                 0.6494
# AUC                0.8464
# Anomaly_Prob       0.3065
# Time_sec           1.6374
# dtype: float64

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import time
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv1D, MaxPooling1D, LSTM, Bidirectional, Dense, Reshape, Dropout, Attention, Concatenate, LayerNormalization, GRU
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import backend as K
from sklearn.metrics import confusion_matrix, roc_auc_score, f1_score
from scipy.spatial.distance import cdist

# ---------------------- Model Definition ----------------------

def f1(y_true, y_pred):
    def recall(y_true, y_pred):
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
        return true_positives / (possible_positives + K.epsilon())

    def precision(y_true, y_pred):
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
        return true_positives / (predicted_positives + K.epsilon())

    p = precision(y_true, y_pred)
    r = recall(y_true, y_pred)
    return 2 * ((p * r) / (p + r + K.epsilon()))

def build_prediction_model(input_shape, output_steps, n_features):
    inputs = Input(shape=input_shape)

    x = Conv1D(filters=64, kernel_size=3, activation='relu', padding='same')(inputs)
    x = MaxPooling1D(pool_size=2)(x)
    x = Bidirectional(GRU(64, return_sequences=True))(x)

    attention = Attention()([x, x])  # Self-attention
    x = Concatenate()([x, attention])
    x = LayerNormalization()(x)
    x = Dropout(0.1)(x)

    x = GRU(64)(x)
    x = Dense(64, activation='relu')(x)
    x = Dense(output_steps * n_features)(x)
    outputs = Reshape((output_steps, n_features))(x)

    model = Model(inputs, outputs)
    model.compile(optimizer=Adam(learning_rate=0.00093286), loss='mse', metrics=['mae', f1])
    return model

def load_trained_model(input_shape, output_steps, n_features):
    model = build_prediction_model(input_shape, output_steps, n_features)
    model.load_weights("gru_epoch_100_10_5.weights.h5")
    return model

# ---------------------- Helper Functions ----------------------

def calculate_entropy(data):
    value_counts = np.bincount(data)
    probabilities = value_counts / np.sum(value_counts)
    probabilities = probabilities[probabilities > 0]
    return -np.sum(probabilities * np.log2(probabilities))

def dynthreshold(vectime, vecvalue):
    packets_int = np.round(vecvalue).astype(int)
    num_points = len(packets_int)
    window_size = 20
    entropy_values = np.array([
        calculate_entropy(packets_int[max(0, i - window_size):i + 1]) for i in range(num_points)
    ])
    H_avg = np.mean(entropy_values)
    sigma = np.std(entropy_values)
    a = 0.2
    T_1 = H_avg + a * sigma
    return entropy_values, T_1, H_avg

def test_single_sequence(model, input_sequence):
    input_seq = np.expand_dims(input_sequence, axis=0)
    prediction = model.predict(input_seq)[0]
    return prediction

def compute_ewma(series, alpha=0.2):
    ewma = np.zeros_like(series)
    ewma[0] = series[0]
    for t in range(1, len(series)):
        ewma[t] = alpha * series[t] + (1 - alpha) * ewma[t - 1]
    return ewma


def compute_residuals(y_true, y_pred, loss_type='rmse'):
    if loss_type == 'rmse':
        return np.sqrt(np.mean((y_true - y_pred) ** 2, axis=1))
    elif loss_type == 'mse':
        return np.mean((y_true - y_pred) ** 2, axis=1)
    elif loss_type == 'mae':
        return np.mean(np.abs(y_true - y_pred), axis=1)
    elif loss_type == 'huber':
        delta = 1.0
        diff = y_true - y_pred
        return np.mean(np.where(np.abs(diff) <= delta,
                                0.5 * diff ** 2,
                                delta * (np.abs(diff) - 0.5 * delta)), axis=1)
    elif loss_type == 'hausdorff':
        return np.array([
            hausdorff_distance(np.expand_dims(y_true[i], axis=0), np.expand_dims(y_pred[i], axis=0))
            for i in range(len(y_true))
        ])
    else:
        raise ValueError(f"Unknown loss type: {loss_type}")

# ---------------------- Main Processing ----------------------

if __name__ == "__main__":
    df = pd.read_csv('All_LOS_DATA_decel_sequence_data_with_jerk.csv')

    look_back = 10
    look_forward = 5
    n_features = 3
    feature_names = ['Speed', 'Acceleration', 'Jerk']
    target_feature = 'Jerk'

    model = load_trained_model(
        input_shape=(look_back, n_features),
        output_steps=look_forward,
        n_features=n_features
    )

    sequences = df[['LOS', 'DepartureTime', 'Iteration']].drop_duplicates()
    # sequences = sequences[
    #     (sequences['LOS'] == 'E') 
    #     # &
    #     # (sequences['DepartureTime'] == 905) 
    # #     # &
    # #     # (sequences['Iteration'] == 17)
    # ]
    # seq_df= df[(df['LOS'] == 'E') & (df['DepartureTime'] == 905) & (df['Iteration'] == 17)]
    metrics_summary = []

    for idx, row in sequences.iterrows():
        start_time = time.time()

        los = row['LOS']
        departure_time = row['DepartureTime']
        iteration = row['Iteration']
        print(los, departure_time, iteration)
        
        seq_df = df[(df['LOS'] == los) & (df['DepartureTime'] == departure_time) & (df['Iteration'] == iteration)]
        if len(seq_df) < (look_back + look_forward):
            continue

        time_sequence = seq_df['Time'].values
        full_features = seq_df[['Speed', 'Acceleration', 'Jerk']].values
        full_labels = seq_df['Label'].values.astype(int)

        all_predictions, all_actuals, all_times, all_labels = [], [], [], []

        for i in range(0, len(full_features) - look_back - look_forward + 1, look_forward):
            current_window = full_features[i:i+look_back]
            actual_continuation = full_features[i+look_back:i+look_back+look_forward]
            time_window = time_sequence[i+look_back:i+look_back+look_forward]
            label_window = full_labels[i+look_back:i+look_back+look_forward]
            prediction = test_single_sequence(model, current_window)
            all_predictions.append(prediction)
            all_actuals.append(actual_continuation)
            all_times.append(time_window)
            all_labels.append(label_window)

        if not all_predictions:
            continue

        all_predictions = np.concatenate(all_predictions)
        all_actuals = np.concatenate(all_actuals)
        all_times = np.concatenate(all_times)
        all_labels = np.concatenate(all_labels)

        predicted_sequence = np.vstack([full_features[:look_back], all_predictions])
        actual_sequence = np.vstack([full_features[:look_back], all_actuals])
        time_plot = np.concatenate([time_sequence[:look_back], all_times])
        test_labels = np.concatenate([full_labels[:look_back], all_labels])

        feature_idx = feature_names.index(target_feature)
        # window_size = 1
        # mse_series = np.array([
        #     np.mean((actual_sequence[t:t+window_size, feature_idx] - predicted_sequence[t:t+window_size, feature_idx]) ** 2)
        #     if t + window_size <= len(predicted_sequence) else 0
        #     for t in range(len(predicted_sequence))
        # ])

        # feature_idx = feature_names.index(target_feature)
        # delta = 1.0

        # # Extract the relevant feature from both sequences
        # y_true = actual_sequence[:, feature_idx]
        # y_pred = predicted_sequence[:, feature_idx]

        # # Compute Huber loss for the whole series
        # diff = y_true - y_pred
        # huber_series = np.where(
        #     np.abs(diff) <= delta,
        #     0.5 * diff ** 2,
        #     delta * (np.abs(diff) - 0.5 * delta)
        # )

        residual_series = compute_residuals(actual_sequence, predicted_sequence, loss_type='huber')

        smoothed_mse = compute_ewma(residual_series[look_back:], 0.3)
        entropy_vals, T1, H_avg = dynthreshold(time_plot[look_back:], smoothed_mse)
        anomalies = (entropy_vals > T1).astype(int)

        y_true = test_labels[look_back:look_back+len(smoothed_mse)]
        y_pred = anomalies

        TP = np.sum((y_pred == 1) & (y_true == 1))
        FP = np.sum((y_pred == 1) & (y_true == 0))
        FN = np.sum((y_pred == 0) & (y_true == 1))
        TN = np.sum((y_pred == 0) & (y_true == 0))

        try:
            auc = roc_auc_score(y_true, entropy_vals)
        except ValueError:
            auc = np.nan

        f1_val = f1_score(y_true, y_pred, zero_division=0)
        prob_detection = (TP / (TP + FN)) * 100 if (TP + FN) > 0 else 0.0
        false_alarm_rate = (FP / (FP + TN)) * 100 if (FP + TN) > 0 else 0.0
        anomaly_probability = (np.sum(y_pred == 1) / len(y_pred)) if len(y_pred) > 0 else 0.0

        end_time = time.time()

        metrics_summary.append({
            'LOS': los,
            'DepartureTime': departure_time,
            'Iteration': iteration,
            'TP': TP,
            'FP': FP,
            'FN': FN,
            'TN': TN,
            'PD': prob_detection,
            'FAR': false_alarm_rate,
            'F1': f1_val,
            'AUC': auc,
            'Anomaly_Prob': anomaly_probability,
            'Time_sec': end_time - start_time
        })

        if metrics_summary:
            metrics_df = pd.DataFrame(metrics_summary)
            numeric_cols = metrics_df.select_dtypes(include=np.number).columns
    
            print(f"\n=== Summary Metrics for Feature: {target_feature} ===")
            print(f"Window Configuration: look_back={look_back}, look_forward={look_forward}")
            print(f"Total sequences analyzed: {len(metrics_df)}\n")
    
            grouped = metrics_df.groupby('LOS')[numeric_cols]
    
            median_metrics = grouped.median().round(4)
            mean_metrics = grouped.mean().round(4)
    
            print("Median Metrics by LOS:")
            print(grouped.median().round(4))
    
            print("\nMean Metrics by LOS:")
            print(grouped.mean().round(4))
    
            median_metrics.to_csv(f"median_metrics_{target_feature}.csv")
            mean_metrics.to_csv(f"mean_metrics_{target_feature}.csv")
        else:
            print(f"No metrics collected for feature: {target_feature}")
# Out:
# 2025-08-18 20:44:00.164924: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-08-18 20:44:00.165412: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-08-18 20:44:00.167891: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-08-18 20:44:00.175462: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1755546240.188786 1145498 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1755546240.192010 1145498 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1755546240.201185 1145498 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1755546240.201206 1145498 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1755546240.201207 1145498 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1755546240.201208 1145498 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-08-18 20:44:00.205226: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# E0000 00:00:1755546241.884852 1145498 cuda_executor.cc:1228] INTERNAL: CUDA Runtime error: Failed call to cudaGetRuntimeVersion: Error loading CUDA libraries. GPU will not be used.: Error loading CUDA libraries. GPU will not be used.
# W0000 00:00:1755546241.887684 1145498 gpu_device.cc:2341] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# /var/data/python/lib/python3.12/site-packages/keras/src/saving/saving_lib.py:757: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 36 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# A 895 1
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 293ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
#
# === Summary Metrics for Feature: Jerk ===
# Window Configuration: look_back=10, look_forward=5
# Total sequences analyzed: 1
#
# Median Metrics by LOS:
#      DepartureTime  Iteration    TP    FP   FN    TN     PD      FAR      F1  \
# LOS
# A            895.0        1.0  21.0  29.0  0.0  45.0  100.0  39.1892  0.5915
#
#         AUC  Anomaly_Prob  Time_sec
# LOS
# A    0.8417        0.5263    1.2414
#
# Mean Metrics by LOS:
#      DepartureTime  Iteration    TP    FP   FN    TN     PD      FAR      F1  \
# LOS
# A            895.0        1.0  21.0  29.0  0.0  45.0  100.0  39.1892  0.5915
#
#         AUC  Anomaly_Prob  Time_sec
# LOS
# A    0.8417        0.5263    1.2414
# A 895 2
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
#
# === Summary Metrics for Feature: Jerk ===
# Window Configuration: look_back=10, look_forward=5
# Total sequences analyzed: 2
#
# Median Metrics by LOS:
#      DepartureTime  Iteration    TP    FP   FN    TN       PD     FAR     F1  \
# LOS
# A            895.0        1.5  19.5  35.5  1.5  38.5  92.8571  47.973  0.518
#
#         AUC  Anomaly_Prob  Time_sec
# LOS
# A    0.6369        0.5789    1.1221
#
# Mean Metrics by LOS:
#      DepartureTime  Iteration    TP    FP   FN    TN       PD     FAR     F1  \
# LOS
# A            895.0        1.5  19.5  35.5  1.5  38.5  92.8571  47.973  0.518
#
#         AUC  Anomaly_Prob  Time_sec
# LOS
# A    0.6369        0.5789    1.1221
# A 895 3
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
#
# === Summary Metrics for Feature: Jerk ===
# Window Configuration: look_back=10, look_forward=5
# Total sequences analyzed: 3
#
# Median Metrics by LOS:
#      DepartureTime  Iteration    TP    FP   FN    TN       PD      FAR  \
# LOS
# A            895.0        2.0  20.0  42.0  1.0  45.0  95.2381  39.1892
#
#          F1     AUC  Anomaly_Prob  Time_sec
# LOS
# A    0.4819  0.7106        0.5263    1.2414
#
# Mean Metrics by LOS:
#      DepartureTime  Iteration       TP       FP      FN       TN       PD  \
# LOS
# A            895.0        2.0  19.6667  37.6667  1.3333  59.6667  93.6508
#
#          FAR     F1     AUC  Anomaly_Prob  Time_sec
# LOS
# A    41.7042  0.506  0.6615        0.5112    1.3135
# A 895 4
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
#
# === Summary Metrics for Feature: Jerk ===
# Window Configuration: look_back=10, look_forward=5
# Total sequences analyzed: 4
#
# Median Metrics by LOS:
#      DepartureTime  Iteration    TP    FP   FN    TN       PD      FAR  \
# LOS
# A            895.0        2.5  20.0  36.5  1.0  41.5  95.2381  42.0584
#
#          F1     AUC  Anomaly_Prob  Time_sec
# LOS
# A    0.5187  0.6716        0.5465    1.1221
#
# Mean Metrics by LOS:
#      DepartureTime  Iteration     TP    FP    FN     TN       PD    FAR  \
# LOS
# A            895.0        2.5  19.75  36.0  1.25  54.25  94.0476  42.51
#
#          F1     AUC  Anomaly_Prob  Time_sec
# LOS
# A    0.5184  0.6542        0.5251    1.2213
# A 895 5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
#
# === Summary Metrics for Feature: Jerk ===
# Window Configuration: look_back=10, look_forward=5
# Total sequences analyzed: 5
#
# Median Metrics by LOS:
#      DepartureTime  Iteration    TP    FP   FN    TN       PD      FAR  \
# LOS
# A            895.0        3.0  20.0  31.0  1.0  45.0  95.2381  39.1892
#
#          F1     AUC  Anomaly_Prob  Time_sec
# LOS
# A    0.5556  0.7106        0.5263    1.0624
#
# Mean Metrics by LOS:
#      DepartureTime  Iteration    TP    FP   FN    TN       PD      FAR  \
# LOS
# A            895.0        3.0  19.8  34.8  1.2  54.2  94.2857  41.1509
#
#          F1     AUC  Anomaly_Prob  Time_sec
# LOS
# A    0.5274  0.6863        0.5153    1.1895
# A 895 6
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
#
# === Summary Metrics for Feature: Jerk ===
# Window Configuration: look_back=10, look_forward=5
# Total sequences analyzed: 6
#
# Median Metrics by LOS:
#      DepartureTime  Iteration    TP    FP   FN    TN       PD      FAR  \
# LOS
# A            895.0        3.5  20.0  30.5  1.0  49.5  95.2381  37.4517
#
#          F1     AUC  Anomaly_Prob  Time_sec
# LOS
# A    0.5595  0.7625        0.5013    1.0766
#
# Mean Metrics by LOS:
#      DepartureTime  Iteration    TP       FP   FN    TN       PD      FAR  \
# LOS
# A            895.0        3.5  20.0  32.6667  1.0  55.5  95.2381  38.6575
#
#          F1     AUC  Anomaly_Prob  Time_sec
# LOS
# A    0.5489  0.7286        0.4977     1.173
# A 895 7
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
#
# === Summary Metrics for Feature: Jerk ===
# Window Configuration: look_back=10, look_forward=5
# Total sequences analyzed: 7
#
# Median Metrics by LOS:
#      DepartureTime  Iteration    TP    FP   FN    TN       PD      FAR  \
# LOS
# A            895.0        4.0  20.0  31.0  1.0  45.0  95.2381  39.1892
#
#          F1     AUC  Anomaly_Prob  Time_sec
# LOS
# A    0.5556  0.7106        0.5263    1.0624
#
# Mean Metrics by LOS:
#      DepartureTime  Iteration       TP    FP      FN       TN       PD  \
# LOS
# A            895.0        4.0  19.5714  36.0  1.4286  50.8571  93.1973
#
#          FAR      F1     AUC  Anomaly_Prob  Time_sec
# LOS
# A    43.2616  0.5221  0.7143        0.5309    1.1508
# A 895 8
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
#
# === Summary Metrics for Feature: Jerk ===
# Window Configuration: look_back=10, look_forward=5
# Total sequences analyzed: 8
#
# Median Metrics by LOS:
#      DepartureTime  Iteration    TP    FP   FN    TN       PD      FAR  \
# LOS
# A            895.0        4.5  20.0  31.0  1.0  41.5  95.2381  42.0584
#
#          F1    AUC  Anomaly_Prob  Time_sec
# LOS
# A    0.5595  0.693        0.5465    1.0398
#
# Mean Metrics by LOS:
#      DepartureTime  Iteration     TP      FP    FN     TN       PD     FAR  \
# LOS
# A            895.0        4.5  19.75  35.375  1.25  46.75  94.0476  45.762
#
#          F1     AUC  Anomaly_Prob  Time_sec
# LOS
# A    0.5288  0.7094        0.5574    1.0963
# A 895 9
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
#
# === Summary Metrics for Feature: Jerk ===
# Window Configuration: look_back=10, look_forward=5
# Total sequences analyzed: 9
#
# Median Metrics by LOS:
#      DepartureTime  Iteration    TP    FP   FN    TN       PD      FAR  \
# LOS
# A            895.0        5.0  20.0  31.0  1.0  38.0  95.2381  44.9275
#
#          F1     AUC  Anomaly_Prob  Time_sec
# LOS
# A    0.5556  0.6754        0.5667    1.0624
#
# Mean Metrics by LOS:
#      DepartureTime  Iteration       TP       FP      FN       TN       PD  \
# LOS
# A            895.0        5.0  19.5556  37.3333  1.4444  45.5556  93.1217
#
#          FAR      F1     AUC  Anomaly_Prob  Time_sec
# LOS
# A    47.2941  0.5135  0.7028        0.5671    1.0983
# A 895 10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
#
# === Summary Metrics for Feature: Jerk ===
# Window Configuration: look_back=10, look_forward=5
# Total sequences analyzed: 10
#
# Median Metrics by LOS:
#      DepartureTime  Iteration    TP    FP   FN    TN       PD      FAR  \
# LOS
# A            895.0        5.5  20.0  32.0  1.0  37.0  95.2381  50.4299
#
#          F1     AUC  Anomaly_Prob  Time_sec
# LOS
# A    0.5381  0.6626        0.5991    1.0398
#
# Mean Metrics by LOS:
#      DepartureTime  Iteration    TP    FP   FN    TN       PD      FAR  \
# LOS
# A            895.0        5.5  19.5  36.9  1.5  43.6  92.8571  48.1579
#
#          F1     AUC  Anomaly_Prob  Time_sec
# LOS
# A    0.5142  0.6975        0.5754    1.0696
# A 895 11
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
#
# === Summary Metrics for Feature: Jerk ===
# Window Configuration: look_back=10, look_forward=5
# Total sequences analyzed: 11
#
# Median Metrics by LOS:
#      DepartureTime  Iteration    TP    FP   FN    TN       PD      FAR  \
# LOS
# A            895.0        6.0  20.0  31.0  1.0  38.0  95.2381  44.9275
#
#          F1     AUC  Anomaly_Prob  Time_sec
# LOS
# A    0.5556  0.6754        0.5667    1.0171
#
# Mean Metrics by LOS:
#      DepartureTime  Iteration       TP       FP      FN       TN       PD  \
# LOS
# A            895.0        6.0  19.6364  35.4545  1.3636  43.5455  93.5065
#
#          FAR      F1    AUC  Anomaly_Prob  Time_sec
# LOS
# A    46.7629  0.5281  0.715         0.568    1.0501
# A 895 12
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
#
# === Summary Metrics for Feature: Jerk ===
# Window Configuration: look_back=10, look_forward=5
# Total sequences analyzed: 12
#
# Median Metrics by LOS:
#      DepartureTime  Iteration    TP    FP   FN    TN       PD      FAR  \
# LOS
# A            895.0        6.5  20.0  32.0  1.0  39.0  95.2381  45.4367
#
#          F1    AUC  Anomaly_Prob  Time_sec
# LOS
# A    0.5444  0.693        0.5675      1.01
#
# Mean Metrics by LOS:
#      DepartureTime  Iteration       TP       FP      FN     TN       PD  \
# LOS
# A            895.0        6.5  19.6667  35.3333  1.3333  43.25  93.6508
#
#          FAR      F1     AUC  Anomaly_Prob  Time_sec
# LOS
# A    46.6948  0.5285  0.7283        0.5681    1.0445
# A 895 13
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
#
# === Summary Metrics for Feature: Jerk ===
# Window Configuration: look_back=10, look_forward=5
# Total sequences analyzed: 13
#
# Median Metrics by LOS:
#      DepartureTime  Iteration    TP    FP   FN    TN       PD      FAR  \
# LOS
# A            895.0        7.0  20.0  33.0  1.0  40.0  95.2381  44.9275
#
#          F1     AUC  Anomaly_Prob  Time_sec
# LOS
# A    0.5556  0.7106        0.5684    1.0028
#
# Mean Metrics by LOS:
#      DepartureTime  Iteration       TP       FP      FN       TN       PD  \
# LOS
# A            895.0        7.0  19.7692  35.1538  1.2308  43.0769  94.1392
#
#          FAR      F1     AUC  Anomaly_Prob  Time_sec
# LOS
# A    46.5332  0.5309  0.7426        0.5681    1.0355
# A 895 14
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
#
# === Summary Metrics for Feature: Jerk ===
# Window Configuration: look_back=10, look_forward=5
# Total sequences analyzed: 14
#
# Median Metrics by LOS:
#      DepartureTime  Iteration    TP    FP   FN    TN       PD      FAR  \
# LOS
# A            895.0        7.5  20.0  33.0  1.0  39.0  95.2381  45.4367
#
#          F1    AUC  Anomaly_Prob  Time_sec
# LOS
# A    0.5444  0.693        0.5675     0.993
#
# Mean Metrics by LOS:
#      DepartureTime  Iteration       TP       FP      FN       TN      PD  \
# LOS
# A            895.0        7.5  18.3571  35.8571  2.6429  42.4286  87.415
#
#          FAR     F1     AUC  Anomaly_Prob  Time_sec
# LOS
# A    47.2782  0.493  0.7049        0.5597    1.0299
# A 895 15
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
#
# === Summary Metrics for Feature: Jerk ===
# Window Configuration: look_back=10, look_forward=5
# Total sequences analyzed: 15
#
# Median Metrics by LOS:
#      DepartureTime  Iteration    TP    FP   FN    TN       PD      FAR  \
# LOS
# A            895.0        8.0  20.0  33.0  1.0  40.0  95.2381  44.9275
#
#          F1     AUC  Anomaly_Prob  Time_sec
# LOS
# A    0.5556  0.7106        0.5667    1.0028
#
# Mean Metrics by LOS:
#      DepartureTime  Iteration       TP       FP      FN    TN       PD  \
# LOS
# A            895.0        8.0  18.4667  33.9333  2.5333  44.4  87.9365
#
#         FAR      F1     AUC  Anomaly_Prob  Time_sec
# LOS
# A    44.717  0.5157  0.7216        0.5404    1.0299
# A 895 16
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
#
# === Summary Metrics for Feature: Jerk ===
# Window Configuration: look_back=10, look_forward=5
# Total sequences analyzed: 16
#
# Median Metrics by LOS:
#      DepartureTime  Iteration    TP    FP   FN    TN       PD      FAR  \
# LOS
# A            895.0        8.5  20.0  33.0  1.0  39.0  95.2381  45.4367
#
#          F1     AUC  Anomaly_Prob  Time_sec
# LOS
# A    0.5444  0.7177        0.5675      1.01
#
# Mean Metrics by LOS:
#      DepartureTime  Iteration       TP      FP      FN       TN       PD  \
# LOS
# A            895.0        8.5  18.4375  35.375  2.5625  43.3125  87.7976
#
#          FAR      F1     AUC  Anomaly_Prob  Time_sec
# LOS
# A    46.1633  0.5069  0.7218        0.5512    1.0312
# A 895 17
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
#
# === Summary Metrics for Feature: Jerk ===
# Window Configuration: look_back=10, look_forward=5
# Total sequences analyzed: 17
#
# Median Metrics by LOS:
#      DepartureTime  Iteration    TP    FP   FN    TN       PD      FAR  \
# LOS
# A            895.0        9.0  20.0  33.0  1.0  40.0  95.2381  45.9459
#
#          F1     AUC  Anomaly_Prob  Time_sec
# LOS
# A    0.5333  0.7152        0.5684    1.0171
#
# Mean Metrics by LOS:
#      DepartureTime  Iteration       TP       FP      FN       TN       PD  \
# LOS
# A            895.0        9.0  18.4706  35.5294  2.5294  43.1765  87.9552
#
#          FAR      F1     AUC  Anomaly_Prob  Time_sec
# LOS
# A    46.2773  0.5057  0.7214        0.5523    1.0316
# A 895 18
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#
# === Summary Metrics for Feature: Jerk ===
# Window Configuration: look_back=10, look_forward=5
# Total sequences analyzed: 18
#
# Median Metrics by LOS:
#      DepartureTime  Iteration    TP    FP   FN    TN       PD      FAR  \
# LOS
# A            895.0        9.5  20.0  33.5  1.0  39.0  95.2381  47.0236
#
#          F1     AUC  Anomaly_Prob  Time_sec
# LOS
# A    0.5269  0.7129        0.5684      1.01
#
# Mean Metrics by LOS:
#      DepartureTime  Iteration       TP    FP      FN       TN       PD  \
# LOS
# A            895.0        9.5  18.4444  36.0  2.5556  41.8889  87.8307
#
#          FAR      F1     AUC  Anomaly_Prob  Time_sec
# LOS
# A    47.5257  0.5017  0.7105        0.5622    1.0218
# A 895 19
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
#
# === Summary Metrics for Feature: Jerk ===
# Window Configuration: look_back=10, look_forward=5
# Total sequences analyzed: 19
#
# Median Metrics by LOS:
#      DepartureTime  Iteration    TP    FP   FN    TN       PD      FAR  \
# LOS
# A            895.0       10.0  20.0  33.0  1.0  40.0  95.2381  45.9459
#
#          F1     AUC  Anomaly_Prob  Time_sec
# LOS
# A    0.5333  0.7152        0.5684    1.0171
#
# Mean Metrics by LOS:
#      DepartureTime  Iteration       TP       FP      FN       TN       PD  \
# LOS
# A            895.0       10.0  18.5789  35.1053  2.4211  44.6842  88.4712
#
#          FAR      F1     AUC  Anomaly_Prob  Time_sec
# LOS
# A    45.9016  0.5116  0.7241        0.5482    1.0428
# A 895 20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
#
# === Summary Metrics for Feature: Jerk ===
# Window Configuration: look_back=10, look_forward=5
# Total sequences analyzed: 20
#
# Median Metrics by LOS:
#      DepartureTime  Iteration    TP    FP   FN    TN       PD      FAR  \
# LOS
# A            895.0       10.5  20.0  33.5  1.0  39.0  95.2381  47.0236
#
#          F1     AUC  Anomaly_Prob  Time_sec
# LOS
# A    0.5269  0.7152        0.5684      1.01
#
# Mean Metrics by LOS:
#      DepartureTime  Iteration     TP    FP   FN     TN       PD      FAR  \
# LOS
# A            895.0       10.5  17.65  36.0  2.3  43.55  84.0476  47.1398
#
#         F1     AUC  Anomaly_Prob  Time_sec
# LOS
# A    0.486  0.7241        0.5561    1.0292
# A 895 21
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# /var/data/python/lib/python3.12/site-packages/sklearn/metrics/_ranking.py:379: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#
# === Summary Metrics for Feature: Jerk ===
# Window Configuration: look_back=10, look_forward=5
# Total sequences analyzed: 21
#
# Median Metrics by LOS:
#      DepartureTime  Iteration    TP    FP   FN    TN       PD      FAR  \
# LOS
# A            895.0       11.0  20.0  33.0  1.0  40.0  95.2381  45.9459
#
#          F1   AUC  Anomaly_Prob  Time_sec
# LOS
# A    0.5333  0.72        0.5684    1.0028
#
# Mean Metrics by LOS:
#      DepartureTime  Iteration       TP       FP      FN       TN       PD  \
# LOS
# A            895.0       11.0  17.7619  34.7143  2.2381  44.5714  84.5805
#
#          FAR      F1     AUC  Anomaly_Prob  Time_sec
# LOS
# A    45.4742  0.5009  0.7351        0.5442    1.0257
# A 895 22
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
#
# === Summary Metrics for Feature: Jerk ===
# Window Configuration: look_back=10, look_forward=5
# Total sequences analyzed: 22
#
# Median Metrics by LOS:
#      DepartureTime  Iteration    TP    FP   FN    TN       PD      FAR  \
# LOS
# A            895.0       11.5  20.0  33.0  1.0  39.0  95.2381  46.4105
#
#          F1     AUC  Anomaly_Prob  Time_sec
# LOS
# A    0.5444  0.7248        0.5684     0.993
#
# Mean Metrics by LOS:
#      DepartureTime  Iteration       TP    FP      FN       TN       PD  \
# LOS
# A            895.0       11.5  17.9091  34.5  2.1364  44.0909  85.2814
#
#          FAR      F1     AUC  Anomaly_Prob  Time_sec
# LOS
# A    45.5379  0.5047  0.7393        0.5467    1.0217
# A 895 23
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
#
# === Summary Metrics for Feature: Jerk ===
# Window Configuration: look_back=10, look_forward=5
# Total sequences analyzed: 23
#
# Median Metrics by LOS:
#      DepartureTime  Iteration    TP    FP   FN    TN       PD     FAR      F1  \
# LOS
# A            895.0       12.0  20.0  33.0  1.0  38.0  95.2381  46.875  0.5333
#
#       AUC  Anomaly_Prob  Time_sec
# LOS
# A    0.72        0.5684    0.9831
#
# Mean Metrics by LOS:
#      DepartureTime  Iteration       TP       FP      FN      TN       PD  \
# LOS
# A            895.0       12.0  18.0435  35.0435  2.0435  42.913  85.9213
#
#          FAR      F1     AUC  Anomaly_Prob  Time_sec
# LOS
# A    46.7509  0.5033  0.7285        0.5577    1.0131
# A 895 24
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#
# === Summary Metrics for Feature: Jerk ===
# Window Configuration: look_back=10, look_forward=5
# Total sequences analyzed: 24
#
# Median Metrics by LOS:
#      DepartureTime  Iteration    TP    FP   FN    TN       PD      FAR  \
# LOS
# A            895.0       12.5  20.0  33.5  1.0  37.0  95.2381  47.4881
#
#          F1     AUC  Anomaly_Prob  Time_sec
# LOS
# A    0.5269  0.7152        0.5692    0.9704
#
# Mean Metrics by LOS:
#      DepartureTime  Iteration       TP     FP      FN       TN       PD  \
# LOS
# A            895.0       12.5  17.8333  35.25  2.2917  41.7083  84.9206
#
#          FAR      F1     AUC  Anomaly_Prob  Time_sec
# LOS
# A    47.8894  0.4969  0.7067        0.5639    1.0001
# A 895 25
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
#
# === Summary Metrics for Feature: Jerk ===
# Window Configuration: look_back=10, look_forward=5
# Total sequences analyzed: 25
#
# Median Metrics by LOS:
#      DepartureTime  Iteration    TP    FP   FN    TN       PD      FAR  \
# LOS
# A            895.0       13.0  20.0  34.0  1.0  38.0  95.2381  47.2973
#
#          F1   AUC  Anomaly_Prob  Time_sec
# LOS
# A    0.5205  0.72        0.5684    0.9577
#
# Mean Metrics by LOS:
#      DepartureTime  Iteration     TP     FP    FN    TN       PD      FAR  \
# LOS
# A            895.0       13.0  17.88  35.24  2.28  41.6  85.1429  47.8657
#
#          F1     AUC  Anomaly_Prob  Time_sec
# LOS
# A    0.4973  0.7099        0.5641     0.996
# A 895 26
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
#
# === Summary Metrics for Feature: Jerk ===
# Window Configuration: look_back=10, look_forward=5
# Total sequences analyzed: 26
#
# Median Metrics by LOS:
#      DepartureTime  Iteration    TP    FP   FN    TN       PD      FAR  \
# LOS
# A            895.0       13.5  20.0  34.5  1.0  37.0  95.2381  47.6993
#
#          F1     AUC  Anomaly_Prob  Time_sec
# LOS
# A    0.5136  0.7248        0.5692    0.9704
#
# Mean Metrics by LOS:
#      DepartureTime  Iteration    TP       FP      FN       TN       PD  \
# LOS
# A            895.0       13.5  18.0  36.6154  2.1923  40.8846  85.7143
#
#          FAR      F1    AUC  Anomaly_Prob  Time_sec
# LOS
# A    48.9298  0.4925  0.711        0.5732    0.9989
# A 895 27
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
#
# === Summary Metrics for Feature: Jerk ===
# Window Configuration: look_back=10, look_forward=5
# Total sequences analyzed: 27
#
# Median Metrics by LOS:
#      DepartureTime  Iteration    TP    FP   FN    TN       PD      FAR  \
# LOS
# A            895.0       14.0  20.0  35.0  1.0  36.0  95.2381  48.1013
#
#          F1   AUC  Anomaly_Prob  Time_sec
# LOS
# A    0.5067  0.72          0.57    0.9831
#
# Mean Metrics by LOS:
# ...
#    1254 def get_concrete_function(self, *args, **kwargs):
#    1255   # Implements PolymorphicFunction.get_concrete_function.
# -> 1256   concrete = self._get_concrete_function_garbage_collected(*args, **kwargs)
#    1257   concrete._garbage_collector.release()  # pylint: disable=protected-access
#    1258   return concrete
#
# File /var/data/python/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:1226, in Function._get_concrete_function_garbage_collected(self, *args, **kwargs)
#    1224   if self._variable_creation_config is None:
#    1225     initializers = []
# -> 1226     self._initialize(args, kwargs, add_initializers_to=initializers)
#    1227     self._initialize_uninitialized_variables(initializers)
#    1229 if self._created_variables:
#    1230   # In this case we have created variables on the first call, so we run the
#    1231   # version which is guaranteed to never create variables.
#
# File /var/data/python/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:696, in Function._initialize(self, args, kwds, add_initializers_to)
#     691 self._variable_creation_config = self._generate_scoped_tracing_options(
#     692     variable_capturing_scope,
#     693     tracing_compilation.ScopeType.VARIABLE_CREATION,
#     694 )
#     695 # Force the definition of the function for these arguments
# --> 696 self._concrete_variable_creation_fn = tracing_compilation.trace_function(
#     697     args, kwds, self._variable_creation_config
#     698 )
#     700 def invalid_creator_scope(*unused_args, **unused_kwds):
#     701   """Disables variable creation."""
#
# File /var/data/python/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py:178, in trace_function(args, kwargs, tracing_options)
#     175     args = tracing_options.input_signature
#     176     kwargs = {}
# --> 178   concrete_function = _maybe_define_function(
#     179       args, kwargs, tracing_options
#     180   )
#     182 if not tracing_options.bind_graph_to_function:
#     183   concrete_function._garbage_collector.release()  # pylint: disable=protected-access
#
# File /var/data/python/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py:283, in _maybe_define_function(args, kwargs, tracing_options)
#     281 else:
#     282   target_func_type = lookup_func_type
# --> 283 concrete_function = _create_concrete_function(
#     284     target_func_type, lookup_func_context, func_graph, tracing_options
#     285 )
#     287 if tracing_options.function_cache is not None:
#     288   tracing_options.function_cache.add(
#     289       concrete_function, current_func_context
#     290   )
#
# File /var/data/python/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py:310, in _create_concrete_function(function_type, type_context, func_graph, tracing_options)
#     303   placeholder_bound_args = function_type.placeholder_arguments(
#     304       placeholder_context
#     305   )
#     307 disable_acd = tracing_options.attributes and tracing_options.attributes.get(
#     308     attributes_lib.DISABLE_ACD, False
#     309 )
# --> 310 traced_func_graph = func_graph_module.func_graph_from_py_func(
#     311     tracing_options.name,
#     312     tracing_options.python_function,
#     313     placeholder_bound_args.args,
#     314     placeholder_bound_args.kwargs,
#     315     None,
#     316     func_graph=func_graph,
#     317     add_control_dependencies=not disable_acd,
#     318     arg_names=function_type_utils.to_arg_names(function_type),
#     319     create_placeholders=False,
#     320 )
#     322 transform.apply_func_graph_transforms(traced_func_graph)
#     324 graph_capture_container = traced_func_graph.function_captures
#
# File /var/data/python/lib/python3.12/site-packages/tensorflow/python/framework/func_graph.py:1060, in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, create_placeholders)
#    1057   return x
#    1059 _, original_func = tf_decorator.unwrap(python_func)
# -> 1060 func_outputs = python_func(*func_args, **func_kwargs)
#    1062 # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#    1063 # TensorArrays and `None`s.
#    1064 func_outputs = variable_utils.convert_variables_to_tensors(func_outputs)
#
# File /var/data/python/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:599, in Function._generate_scoped_tracing_options.<locals>.wrapped_fn(*args, **kwds)
#     595 with default_graph._variable_creator_scope(scope, priority=50):  # pylint: disable=protected-access
#     596   # __wrapped__ allows AutoGraph to swap in a converted function. We give
#     597   # the function a weak reference to itself to avoid a reference cycle.
#     598   with OptionalXlaContext(compile_with_xla):
# --> 599     out = weak_wrapped_fn().__wrapped__(*args, **kwds)
#     600   return out
#
# File /var/data/python/lib/python3.12/site-packages/tensorflow/python/data/ops/structured_function.py:231, in StructuredFunctionWrapper.__init__.<locals>.trace_tf_function.<locals>.wrapped_fn(*args)
#     230 def wrapped_fn(*args):  # pylint: disable=missing-docstring
# --> 231   ret = wrapper_helper(*args)
#     232   ret = structure.to_tensor_list(self._output_structure, ret)
#     233   return [ops.convert_to_tensor(t) for t in ret]
#
# File /var/data/python/lib/python3.12/site-packages/tensorflow/python/data/ops/structured_function.py:161, in StructuredFunctionWrapper.__init__.<locals>.wrapper_helper(*args)
#     159 if not _should_unpack(nested_args):
#     160   nested_args = (nested_args,)
# --> 161 ret = autograph.tf_convert(self._func, ag_ctx)(*nested_args)
#     162 ret = variable_utils.convert_variables_to_tensors(ret)
#     163 if _should_pack(ret):
#
# File /var/data/python/lib/python3.12/site-packages/tensorflow/python/autograph/impl/api.py:690, in convert.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     688 try:
#     689   with conversion_ctx:
# --> 690     return converted_call(f, args, kwargs, options=options)
#     691 except Exception as e:  # pylint:disable=broad-except
#     692   if hasattr(e, 'ag_error_metadata'):
#
# File /var/data/python/lib/python3.12/site-packages/tensorflow/python/autograph/impl/api.py:377, in converted_call(f, args, kwargs, caller_fn_scope, options)
#     374   return _call_unconverted(f, args, kwargs, options)
#     376 if not options.user_requested and conversion.is_allowlisted(f):
# --> 377   return _call_unconverted(f, args, kwargs, options)
#     379 # internal_convert_user_code is for example turned off when issuing a dynamic
#     380 # call conversion from generated code while in nonrecursive mode. In that
#     381 # case we evidently don't want to recurse, but we still have to convert
#     382 # things like builtins.
#     383 if not options.internal_convert_user_code:
#
# File /var/data/python/lib/python3.12/site-packages/tensorflow/python/autograph/impl/api.py:459, in _call_unconverted(f, args, kwargs, options, update_cache)
#     456   return f.__self__.call(args, kwargs)
#     458 if kwargs is not None:
# --> 459   return f(*args, **kwargs)
#     460 return f(*args)
#
# File /var/data/python/lib/python3.12/site-packages/keras/src/trainers/data_adapters/array_data_adapter.py:168, in ArrayDataAdapter.get_tf_dataset.<locals>.slice_batch_indices(indices)
#     165 flat_dataset = tf.data.Dataset.from_tensor_slices(first_k_indices)
#     166 if self._partial_batch_size:
#     167     index_remainder = tf.data.Dataset.from_tensors(
# --> 168         tf.slice(
#     169             indices, [num_in_full_batch], [self._partial_batch_size]
#     170         )
#     171     )
#     172     flat_dataset = flat_dataset.concatenate(index_remainder)
#     174 return flat_dataset
#
# File /var/data/python/lib/python3.12/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /var/data/python/lib/python3.12/site-packages/tensorflow/python/util/dispatch.py:1260, in add_dispatch_support.<locals>.decorator.<locals>.op_dispatch_handler(*args, **kwargs)
#    1258 # Fallback dispatch system (dispatch v1):
#    1259 try:
# -> 1260   return dispatch_target(*args, **kwargs)
#    1261 except (TypeError, ValueError):
#    1262   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1263   # TypeError, when given unexpected types.  So we need to catch both.
#    1264   result = dispatch(op_dispatch_handler, args, kwargs)
#
# File /var/data/python/lib/python3.12/site-packages/tensorflow/python/ops/array_ops.py:991, in slice(input_, begin, size, name)
#     939 @tf_export("slice")
#     940 @dispatch.add_dispatch_support
#     941 def slice(input_, begin, size, name=None):
#     942   # pylint: disable=redefined-builtin
#     943   """Extracts a slice from a tensor.
#     944
#     945   See also `tf.strided_slice`.
#    (...)    989     A `Tensor` the same type as `input_`.
#     990   """
# --> 991   return gen_array_ops._slice(input_, begin, size, name=name)
#
# File /var/data/python/lib/python3.12/site-packages/tensorflow/python/ops/gen_array_ops.py:9901, in _slice(input, begin, size, name)
#    9899     pass  # Add nodes to the TensorFlow graph.
#    9900 # Add nodes to the TensorFlow graph.
# -> 9901 _, _, _op, _outputs = _op_def_library._apply_op_helper(
#    9902       "Slice", input=input, begin=begin, size=size, name=name)
#    9903 _result = _outputs[:]
#    9904 if _execute.must_record_gradient():
#
# File /var/data/python/lib/python3.12/site-packages/tensorflow/python/framework/op_def_library.py:778, in _apply_op_helper(op_type_name, name, **keywords)
#     776 with g.as_default(), ops.name_scope(name) as scope:
#     777   if fallback:
# --> 778     _ExtractInputsAndAttrs(op_type_name, op_def, allowed_list_attr_map,
#     779                            keywords, default_type_attr_map, attrs, inputs,
#     780                            input_types)
#     781     _ExtractRemainingAttrs(op_type_name, op_def, keywords,
#     782                            default_type_attr_map, attrs)
#     783     _ExtractAttrProto(op_type_name, op_def, attrs, attr_protos)
#
# File /var/data/python/lib/python3.12/site-packages/tensorflow/python/framework/op_def_library.py:551, in _ExtractInputsAndAttrs(op_type_name, op_def, allowed_list_attr_map, keywords, default_type_attr_map, attrs, inputs, input_types)
#     545       values = ops.convert_to_tensor(
#     546           values,
#     547           name=input_arg.name,
#     548           as_ref=input_arg.is_ref,
#     549           preferred_dtype=default_dtype)
#     550   else:
# --> 551     values = ops.convert_to_tensor(
#     552         values,
#     553         name=input_arg.name,
#     554         dtype=dtype,
#     555         as_ref=input_arg.is_ref,
#     556         preferred_dtype=default_dtype)
#     557 except TypeError as err:
#     558   if dtype is None:
#
# File /var/data/python/lib/python3.12/site-packages/tensorflow/python/profiler/trace.py:183, in trace_wrapper.<locals>.inner_wrapper.<locals>.wrapped(*args, **kwargs)
#     181   with Trace(trace_name, **trace_kwargs):
#     182     return func(*args, **kwargs)
# --> 183 return func(*args, **kwargs)
#
# File /var/data/python/lib/python3.12/site-packages/tensorflow/python/framework/ops.py:736, in convert_to_tensor(value, dtype, name, as_ref, preferred_dtype, dtype_hint, ctx, accepted_result_types)
#     734 # TODO(b/142518781): Fix all call-sites and remove redundant arg
#     735 preferred_dtype = preferred_dtype or dtype_hint
# --> 736 return tensor_conversion_registry.convert(
#     737     value, dtype, name, as_ref, preferred_dtype, accepted_result_types
#     738 )
#
# File /var/data/python/lib/python3.12/site-packages/tensorflow/python/framework/tensor_conversion_registry.py:234, in convert(value, dtype, name, as_ref, preferred_dtype, accepted_result_types)
#     225       raise RuntimeError(
#     226           _add_error_prefix(
#     227               f"Conversion function {conversion_func!r} for type "
#    (...)    230               f"actual = {ret.dtype.base_dtype.name}",
#     231               name=name))
#     233 if ret is None:
# --> 234   ret = conversion_func(value, dtype=dtype, name=name, as_ref=as_ref)
#     236 if ret is NotImplemented:
#     237   continue
#
# File /var/data/python/lib/python3.12/site-packages/tensorflow/python/framework/constant_tensor_conversion.py:29, in _constant_tensor_conversion_function(v, dtype, name, as_ref)
#      26 from tensorflow.python.framework import constant_op  # pylint: disable=g-import-not-at-top
#      28 _ = as_ref
# ---> 29 return constant_op.constant(v, dtype=dtype, name=name)
#
# File /var/data/python/lib/python3.12/site-packages/tensorflow/python/ops/weak_tensor_ops.py:142, in weak_tensor_binary_op_wrapper.<locals>.wrapper(*args, **kwargs)
#     140 def wrapper(*args, **kwargs):
#     141   if not ops.is_auto_dtype_conversion_enabled():
# --> 142     return op(*args, **kwargs)
#     143   bound_arguments = signature.bind(*args, **kwargs)
#     144   bound_arguments.apply_defaults()
#
# File /var/data/python/lib/python3.12/site-packages/tensorflow/python/framework/constant_op.py:276, in constant(value, dtype, shape, name)
#     177 @tf_export("constant", v1=[])
#     178 def constant(
#     179     value, dtype=None, shape=None, name="Const"
#     180 ) -> Union[ops.Operation, ops._EagerTensorBase]:
#     181   """Creates a constant tensor from a tensor-like object.
#     182
#     183   Note: All eager `tf.Tensor` values are immutable (in contrast to
#    (...)    274     ValueError: if called on a symbolic tensor.
#     275   """
# --> 276   return _constant_impl(value, dtype, shape, name, verify_shape=False,
#     277                         allow_broadcast=True)
#
# File /var/data/python/lib/python3.12/site-packages/tensorflow/python/framework/constant_op.py:291, in _constant_impl(value, dtype, shape, name, verify_shape, allow_broadcast)
#     288       return _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
#     289   return _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
# --> 291 const_tensor = ops._create_graph_constant(  # pylint: disable=protected-access
#     292     value, dtype, shape, name, verify_shape, allow_broadcast
#     293 )
#     294 return const_tensor
#
# File /var/data/python/lib/python3.12/site-packages/tensorflow/python/framework/ops.py:284, in _create_graph_constant(value, dtype, shape, name, verify_shape, allow_broadcast)
#     281 g = get_default_graph()
#     282 tensor_value = attr_value_pb2.AttrValue()
#     283 tensor_value.tensor.CopyFrom(
# --> 284     tensor_util.make_tensor_proto(
#     285         value, dtype=dtype, shape=shape, verify_shape=verify_shape,
#     286         allow_broadcast=allow_broadcast))
#     287 dtype_value = attr_value_pb2.AttrValue(type=tensor_value.tensor.dtype)
#     288 attrs = {"value": tensor_value, "dtype": dtype_value}
#
# File /var/data/python/lib/python3.12/site-packages/tensorflow/python/framework/tensor_util.py:701, in make_tensor_proto(values, dtype, shape, verify_shape, allow_broadcast)
#     698 if append_fn is None:
#     699   raise TypeError(
#     700       f"Element type not supported in TensorProto: {numpy_dtype.name}.")
# --> 701 append_fn(tensor_proto, proto_values)
#     703 return tensor_proto
#
# File /var/data/python/lib/python3.12/site-packages/tensorflow/python/framework/tensor_util.py:245, in SlowAppendIntArrayToTensorProto(tensor_proto, proto_values)
#     242 def SlowAppendFloat64ArrayToTensorProto(tensor_proto, proto_values):
#     243   tensor_proto.double_val.extend([x.item() for x in proto_values])
# --> 245 def SlowAppendIntArrayToTensorProto(tensor_proto, proto_values):
#     246   tensor_proto.int_val.extend([x.item() for x in proto_values])
#     248 def SlowAppendInt64ArrayToTensorProto(tensor_proto, proto_values):
#
# KeyboardInterrupt:

# %% [markdown]
# # Youden J index

# %%
import numpy as np
from tensorflow.keras.optimizers import Adam
import matplotlib.pyplot as plt
from scipy.spatial.distance import cdist
import pandas as pd
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import (Input, Conv1D, MaxPooling1D, 
                                     GRU, Bidirectional, Dense, 
                                     Reshape, Dropout, Attention, 
                                     Concatenate, LayerNormalization)
from tensorflow.keras import backend as K
from sklearn.metrics import mean_absolute_error, mean_squared_error

# --- Plotting functions ---
def plot_optimization_results(agg_results, top_n=10):
    top = agg_results.sort_values(by='Youden_index', ascending=False).head(top_n)
    plt.figure(figsize=(12, 6))
    scatter = plt.scatter(top['a'], top['window_size'],
                          c=top['Youden_index'], cmap='viridis', s=100, edgecolor='k')
    plt.colorbar(scatter, label='Youden Index')
    for i, row in top.iterrows():
        plt.text(row['a'], row['window_size'], row['loss_func'], fontsize=9,
                 ha='center', va='center', color='white', weight='bold')
    plt.title(f'Top {top_n} Hyperparameter Combinations by Youden Index')
    plt.xlabel('Threshold Scaling (a)')
    plt.ylabel('Window Size')
    plt.grid(True)
    plt.tight_layout()
    plt.show()

def plot_pd_vs_far(agg_results):
    plt.figure(figsize=(8, 6))
    scatter = plt.scatter(agg_results['FAR'], agg_results['PD'],
                          c=agg_results['Youden_index'], cmap='plasma', s=80, edgecolor='k')
    plt.colorbar(scatter, label='Youden Index')
    plt.title('PD vs FAR for Hyperparameter Combinations')
    plt.xlabel('False Alarm Rate (FAR)')
    plt.ylabel('Probability of Detection (PD)')
    plt.grid(True)
    plt.tight_layout()
    plt.show()

# --- Model definition ---
def build_prediction_model(input_shape, output_steps, n_features):
    inputs = Input(shape=input_shape)
    x = Conv1D(filters=64, kernel_size=3, activation='relu', padding='same')(inputs)
    x = MaxPooling1D(pool_size=2)(x)
    x = Bidirectional(GRU(64, return_sequences=True))(x)
    attention = Attention()([x, x])
    x = Concatenate()([x, attention])
    x = LayerNormalization()(x)
    x = Dropout(0.1)(x)
    x = GRU(64)(x)
    x = Dense(64, activation='relu')(x)
    x = Dense(output_steps * n_features)(x)
    outputs = Reshape((output_steps, n_features))(x)
    model = Model(inputs, outputs)
    model.compile(optimizer=Adam(learning_rate=0.00093286), loss='mse', metrics=['mae', f1])
    return model

def load_trained_model(input_shape, output_steps, n_features):
    model = build_prediction_model(input_shape, output_steps, n_features)
    model.load_weights("gru_epoch_100_10_5.weights.h5")  # make sure this file exists
    return model

# --- Custom metric ---
def f1(y_true, y_pred):
    def recall(y_true, y_pred):
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
        return true_positives / (possible_positives + K.epsilon())

    def precision(y_true, y_pred):
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
        return true_positives / (predicted_positives + K.epsilon())

    p = precision(y_true, y_pred)
    r = recall(y_true, y_pred)
    return 2 * ((p * r) / (p + r + K.epsilon()))

# --- Utility functions ---
def calculate_entropy(data):
    value_counts = np.bincount(data)
    probabilities = value_counts / np.sum(value_counts)
    probabilities = probabilities[probabilities > 0]
    return -np.sum(probabilities * np.log2(probabilities))

def hausdorff_distance(set1, set2):
    dists = cdist(set1, set2, metric='euclidean')
    forward = np.max(np.min(dists, axis=1))
    backward = np.max(np.min(dists, axis=0))
    return max(forward, backward)

def compute_residuals(y_true, y_pred, loss_type='rmse'):
    if loss_type == 'rmse':
        return np.sqrt(np.mean((y_true - y_pred) ** 2, axis=1))
    elif loss_type == 'mse':
        return np.mean((y_true - y_pred) ** 2, axis=1)
    elif loss_type == 'mae':
        return np.mean(np.abs(y_true - y_pred), axis=1)
    elif loss_type == 'huber':
        delta = 1.0
        diff = y_true - y_pred
        return np.mean(np.where(np.abs(diff) <= delta,
                                0.5 * diff ** 2,
                                delta * (np.abs(diff) - 0.5 * delta)), axis=1)
    elif loss_type == 'hausdorff':
        return np.array([
            hausdorff_distance(np.expand_dims(y_true[i], axis=0), np.expand_dims(y_pred[i], axis=0))
            for i in range(len(y_true))
        ])
    else:
        raise ValueError(f"Unknown loss type: {loss_type}")

def compute_ewma(series, alpha=0.2):
    ewma = np.zeros_like(series)
    ewma[0] = series[0]
    for t in range(1, len(series)):
        ewma[t] = alpha * series[t] + (1 - alpha) * ewma[t - 1]
    return ewma

# --- Core optimization function ---
def optimize_anomaly_detection_on_all_sequences(df, model, feature_names=['Speed', 'Acceleration', 'Jerk'], look_back=10, look_forward=5):
    a_range = np.linspace(-2, 2, int((2 - (-2)) / 0.1) + 1)
    window_sizes = [5, 10, 15, 20]
    loss_functions = ['rmse', 'mse', 'mae', 'huber', 'hausdorff']
    alphas = np.linspace(0, 1, int((1 - 0) / 0.1) + 1)
    results = []

    for los in ['A', 'B', 'C', 'D', 'E']:
        for dep_time in range(895, 906):
            for iteration in range(1, 31):
                seq_df = df[(df['LOS'] == los) &
                            (df['DepartureTime'] == dep_time) &
                            (df['Iteration'] == iteration)]

                if len(seq_df) < look_back + look_forward:
                    continue

                print(f"Processing LOS {los}, Departure {dep_time}, Iteration {iteration}")
                time_sequence = seq_df['Time'].values
                full_features = seq_df[feature_names].values
                full_labels = seq_df['Label'].values.astype(int)

                all_predictions, all_actuals, all_times = [], [], []

                for i in range(0, len(full_features) - look_back - look_forward + 1, look_forward):
                    current_window = full_features[i:i+look_back]
                    actual_continuation = full_features[i+look_back:i+look_back+look_forward]
                    time_window = time_sequence[i+look_back:i+look_back+look_forward]
                    prediction = model.predict(np.expand_dims(current_window, axis=0), verbose=0)[0]
                    all_predictions.append(prediction)
                    all_actuals.append(actual_continuation)
                    all_times.append(time_window)

                if not all_predictions:
                    continue

                prediction = np.concatenate(all_predictions)
                actual = np.concatenate(all_actuals)

                # ✅ Focus only on Jerk (column index 2)
                jerk_index = feature_names.index('Jerk')
                prediction = prediction[:, jerk_index].reshape(-1, 1)
                actual = actual[:, jerk_index].reshape(-1, 1)

                test_labels = full_labels[:look_back + len(prediction)]

                for loss in loss_functions:
                    # compute residuals once per (loss, seq)
                    residual_series = compute_residuals(actual, prediction, loss_type=loss)
                    for window_size in window_sizes:
                        for alpha in alphas:
                            smoothed = compute_ewma(residual_series, alpha)
                            # precompute entropies for this (loss, window_size, alpha)
                            entropy_vals = np.array([
                                calculate_entropy(np.round(smoothed[max(0, i - window_size):i + 1]).astype(int))
                                for i in range(len(smoothed))
                            ])
                            H_avg = np.mean(entropy_vals)
                            sigma = np.std(entropy_vals)

                            for a in a_range:
                                T1 = H_avg + a * sigma
                                anomalies = (entropy_vals > T1).astype(int)

                                y_true = test_labels[look_back:look_back + len(prediction)]
                                y_pred = anomalies[:len(y_true)]

                                TP = np.sum((y_pred == 1) & (y_true == 1))
                                FN = np.sum((y_pred == 0) & (y_true == 1))
                                FP = np.sum((y_pred == 1) & (y_true == 0))
                                TN = np.sum((y_pred == 0) & (y_true == 0))

                                PD = TP / (TP + FN) if (TP + FN) > 0 else 0
                                FAR = FP / (FP + TN) if (FP + TN) > 0 else 0
                                YI = PD - FAR

                                results.append({
                                    'LOS': los,
                                    'DepartureTime': dep_time,
                                    'Iteration': iteration,
                                    'a': a,
                                    'window_size': window_size,
                                    'loss_func': loss,
                                    'alpha': alpha,
                                    'PD': PD,
                                    'FAR': FAR,
                                    'Youden_index': YI
                                })

    # ---- aggregation (per-LOS) ----
    df_results = pd.DataFrame(results)

    # Mean aggregation per LOS
    agg_mean = (
        df_results
        .groupby(['LOS', 'a', 'window_size', 'loss_func', 'alpha'], as_index=False)
        .agg(PD_mean=('PD', 'mean'), FAR_mean=('FAR', 'mean'))
    )
    agg_mean['Youden_index'] = agg_mean['PD_mean'] - agg_mean['FAR_mean']

    # Median aggregation per LOS
    agg_median = (
        df_results
        .groupby(['LOS', 'a', 'window_size', 'loss_func', 'alpha'], as_index=False)
        .agg(PD_median=('PD', 'median'), FAR_median=('FAR', 'median'))
    )
    agg_median['Youden_index_median'] = agg_median['PD_median'] - agg_median['FAR_median']

    # Save per-LOS CSVs and print top-10 for each LOS
    for los in ['A', 'B', 'C', 'D', 'E']:
        mean_los = agg_mean[agg_mean['LOS'] == los].sort_values('Youden_index', ascending=False)
        median_los = agg_median[agg_median['LOS'] == los].sort_values('Youden_index_median', ascending=False)

        mean_los.to_csv(f"top_parameter_combinations_LOS_{los}_mean.csv", index=False)
        median_los.to_csv(f"top_parameter_combinations_LOS_{los}_median.csv", index=False)

        print(f"\nTop 10 parameter combinations for LOS {los} (by mean Youden):")
        print(mean_los.head(10))

        print(f"\nTop 10 parameter combinations for LOS {los} (by median Youden):")
        print(median_los.head(10))

    # (Optional) also save combined (all LOS together) tables for convenience
    agg_mean.sort_values(['LOS', 'Youden_index'], ascending=[True, False]).to_csv(
        "top_parameter_combinations_ALL_LOS_mean.csv", index=False)
    agg_median.sort_values(['LOS', 'Youden_index_median'], ascending=[True, False]).to_csv(
        "top_parameter_combinations_ALL_LOS_median.csv", index=False)

    # Return dicts of top-10 per LOS for quick access if needed
    top10_mean = {
        los: agg_mean[agg_mean['LOS'] == los].sort_values('Youden_index', ascending=False).head(10)
        for los in ['A', 'B', 'C', 'D', 'E']
    }
    top10_median = {
        los: agg_median[agg_median['LOS'] == los].sort_values('Youden_index_median', ascending=False).head(10)
        for los in ['A', 'B', 'C', 'D', 'E']
    }

    return top10_mean, top10_median, agg_mean, agg_median

# --- MAIN ---
if __name__ == "__main__":
    look_back = 10
    look_forward = 5
    feature_names = ['Speed', 'Acceleration', 'Jerk']
    n_features = len(feature_names)

    model = load_trained_model(
        input_shape=(look_back, n_features),
        output_steps=look_forward,
        n_features=n_features
    )

    df = pd.read_csv('All_LOS_DATA_decel_sequence_data_with_jerk.csv')

    top10_results, agg_results = optimize_anomaly_detection_on_all_sequences(
        df=df,
        model=model,
        feature_names=feature_names,
        look_back=look_back,
        look_forward=look_forward
    )
# Out:
# /var/data/python/lib/python3.12/site-packages/keras/src/saving/saving_lib.py:757: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 36 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# Processing LOS A, Departure 895, Iteration 1
# Processing LOS A, Departure 895, Iteration 2
# Processing LOS A, Departure 895, Iteration 3
# Processing LOS A, Departure 895, Iteration 4
# Processing LOS A, Departure 895, Iteration 5
# Processing LOS A, Departure 895, Iteration 6
# Processing LOS A, Departure 895, Iteration 7
# Processing LOS A, Departure 895, Iteration 8
# Processing LOS A, Departure 895, Iteration 9
# Processing LOS A, Departure 895, Iteration 10
# Processing LOS A, Departure 895, Iteration 11
# Processing LOS A, Departure 895, Iteration 12
# Processing LOS A, Departure 895, Iteration 13
# Processing LOS A, Departure 895, Iteration 14
# Processing LOS A, Departure 895, Iteration 15
# Processing LOS A, Departure 895, Iteration 16
# Processing LOS A, Departure 895, Iteration 17
# Processing LOS A, Departure 895, Iteration 18
# Processing LOS A, Departure 895, Iteration 19
# Processing LOS A, Departure 895, Iteration 20
# Processing LOS A, Departure 895, Iteration 21
# Processing LOS A, Departure 895, Iteration 22
# Processing LOS A, Departure 895, Iteration 23
# Processing LOS A, Departure 895, Iteration 24
# Processing LOS A, Departure 895, Iteration 25
# Processing LOS A, Departure 895, Iteration 26
# Processing LOS A, Departure 895, Iteration 27
# Processing LOS A, Departure 895, Iteration 28
# Processing LOS A, Departure 895, Iteration 29
# Processing LOS A, Departure 895, Iteration 30
# Processing LOS A, Departure 896, Iteration 1
# Processing LOS A, Departure 896, Iteration 2
# Processing LOS A, Departure 896, Iteration 3
# Processing LOS A, Departure 896, Iteration 4
# Processing LOS A, Departure 896, Iteration 5
# Processing LOS A, Departure 896, Iteration 6
# Processing LOS A, Departure 896, Iteration 7
# Processing LOS A, Departure 896, Iteration 8
# Processing LOS A, Departure 896, Iteration 9
# Processing LOS A, Departure 896, Iteration 10
# Processing LOS A, Departure 896, Iteration 11
# Processing LOS A, Departure 896, Iteration 12
# Processing LOS A, Departure 896, Iteration 13
# Processing LOS A, Departure 896, Iteration 14
# Processing LOS A, Departure 896, Iteration 15
# Processing LOS A, Departure 896, Iteration 16
# Processing LOS A, Departure 896, Iteration 17
# Processing LOS A, Departure 896, Iteration 18
# Processing LOS A, Departure 896, Iteration 19
# Processing LOS A, Departure 896, Iteration 20
# Processing LOS A, Departure 896, Iteration 21
# Processing LOS A, Departure 896, Iteration 22
# Processing LOS A, Departure 896, Iteration 23
# Processing LOS A, Departure 896, Iteration 24
# Processing LOS A, Departure 896, Iteration 25
# Processing LOS A, Departure 896, Iteration 26
# Processing LOS A, Departure 896, Iteration 27
# Processing LOS A, Departure 896, Iteration 28
# Processing LOS A, Departure 896, Iteration 29
# Processing LOS A, Departure 896, Iteration 30
# Processing LOS A, Departure 897, Iteration 1
# Processing LOS A, Departure 897, Iteration 2
# Processing LOS A, Departure 897, Iteration 3
# Processing LOS A, Departure 897, Iteration 4
# Processing LOS A, Departure 897, Iteration 5
# Processing LOS A, Departure 897, Iteration 6
# Processing LOS A, Departure 897, Iteration 7
# Processing LOS A, Departure 897, Iteration 8
# Processing LOS A, Departure 897, Iteration 9
# Processing LOS A, Departure 897, Iteration 10
# Processing LOS A, Departure 897, Iteration 11
# Processing LOS A, Departure 897, Iteration 12
# Processing LOS A, Departure 897, Iteration 13
# Processing LOS A, Departure 897, Iteration 14
# Processing LOS A, Departure 897, Iteration 15
# Processing LOS A, Departure 897, Iteration 16
# Processing LOS A, Departure 897, Iteration 17
# Processing LOS A, Departure 897, Iteration 18
# Processing LOS A, Departure 897, Iteration 19
# Processing LOS A, Departure 897, Iteration 20
# Processing LOS A, Departure 897, Iteration 21
# Processing LOS A, Departure 897, Iteration 22
# Processing LOS A, Departure 897, Iteration 23
# Processing LOS A, Departure 897, Iteration 24
# Processing LOS A, Departure 897, Iteration 25
# Processing LOS A, Departure 897, Iteration 26
# Processing LOS A, Departure 897, Iteration 27
# Processing LOS A, Departure 897, Iteration 28
# Processing LOS A, Departure 897, Iteration 29
# Processing LOS A, Departure 897, Iteration 30
# Processing LOS A, Departure 898, Iteration 1
# Processing LOS A, Departure 898, Iteration 2
# Processing LOS A, Departure 898, Iteration 3
# Processing LOS A, Departure 898, Iteration 4
# Processing LOS A, Departure 898, Iteration 5
# Processing LOS A, Departure 898, Iteration 6
# Processing LOS A, Departure 898, Iteration 7
# Processing LOS A, Departure 898, Iteration 8
# Processing LOS A, Departure 898, Iteration 9
# Processing LOS A, Departure 898, Iteration 10
# Processing LOS A, Departure 898, Iteration 11
# Processing LOS A, Departure 898, Iteration 12
# Processing LOS A, Departure 898, Iteration 13
# Processing LOS A, Departure 898, Iteration 14
# Processing LOS A, Departure 898, Iteration 15
# Processing LOS A, Departure 898, Iteration 16
# Processing LOS A, Departure 898, Iteration 17
# Processing LOS A, Departure 898, Iteration 18
# Processing LOS A, Departure 898, Iteration 19
# Processing LOS A, Departure 898, Iteration 20
# Processing LOS A, Departure 898, Iteration 21
# Processing LOS A, Departure 898, Iteration 22
# Processing LOS A, Departure 898, Iteration 23
# Processing LOS A, Departure 898, Iteration 24
# Processing LOS A, Departure 898, Iteration 25
# Processing LOS A, Departure 898, Iteration 26
# Processing LOS A, Departure 898, Iteration 27
# Processing LOS A, Departure 898, Iteration 28
# Processing LOS A, Departure 898, Iteration 29
# Processing LOS A, Departure 898, Iteration 30
# Processing LOS A, Departure 899, Iteration 1
# Processing LOS A, Departure 899, Iteration 2
# Processing LOS A, Departure 899, Iteration 3
# Processing LOS A, Departure 899, Iteration 4
# Processing LOS A, Departure 899, Iteration 5
# Processing LOS A, Departure 899, Iteration 6
# Processing LOS A, Departure 899, Iteration 7
# Processing LOS A, Departure 899, Iteration 8
# Processing LOS A, Departure 899, Iteration 9
# Processing LOS A, Departure 899, Iteration 10
# Processing LOS A, Departure 899, Iteration 11
# Processing LOS A, Departure 899, Iteration 12
# Processing LOS A, Departure 899, Iteration 13
# Processing LOS A, Departure 899, Iteration 14
# Processing LOS A, Departure 899, Iteration 15
# Processing LOS A, Departure 899, Iteration 16
# Processing LOS A, Departure 899, Iteration 17
# Processing LOS A, Departure 899, Iteration 18
# Processing LOS A, Departure 899, Iteration 19
# Processing LOS A, Departure 899, Iteration 20
# Processing LOS A, Departure 899, Iteration 21
# Processing LOS A, Departure 899, Iteration 22
# Processing LOS A, Departure 899, Iteration 23
# Processing LOS A, Departure 899, Iteration 24
# Processing LOS A, Departure 899, Iteration 25
# Processing LOS A, Departure 899, Iteration 26
# Processing LOS A, Departure 899, Iteration 27
# Processing LOS A, Departure 899, Iteration 28
# Processing LOS A, Departure 899, Iteration 29
# Processing LOS A, Departure 899, Iteration 30
# Processing LOS A, Departure 900, Iteration 1
# Processing LOS A, Departure 900, Iteration 2
# Processing LOS A, Departure 900, Iteration 3
# Processing LOS A, Departure 900, Iteration 4
# Processing LOS A, Departure 900, Iteration 5
# Processing LOS A, Departure 900, Iteration 6
# Processing LOS A, Departure 900, Iteration 7
# Processing LOS A, Departure 900, Iteration 8
# Processing LOS A, Departure 900, Iteration 9
# Processing LOS A, Departure 900, Iteration 10
# Processing LOS A, Departure 900, Iteration 11
# Processing LOS A, Departure 900, Iteration 12
# Processing LOS A, Departure 900, Iteration 13
# Processing LOS A, Departure 900, Iteration 14
# Processing LOS A, Departure 900, Iteration 15
# Processing LOS A, Departure 900, Iteration 16
# Processing LOS A, Departure 900, Iteration 17
# Processing LOS A, Departure 900, Iteration 18
# Processing LOS A, Departure 900, Iteration 19
# Processing LOS A, Departure 900, Iteration 20
# Processing LOS A, Departure 900, Iteration 21
# Processing LOS A, Departure 900, Iteration 22
# Processing LOS A, Departure 900, Iteration 23
# Processing LOS A, Departure 900, Iteration 24
# Processing LOS A, Departure 900, Iteration 25
# Processing LOS A, Departure 900, Iteration 26
# Processing LOS A, Departure 900, Iteration 27
# Processing LOS A, Departure 900, Iteration 28
# Processing LOS A, Departure 900, Iteration 29
# Processing LOS A, Departure 900, Iteration 30
# Processing LOS A, Departure 901, Iteration 1
# Processing LOS A, Departure 901, Iteration 2
# Processing LOS A, Departure 901, Iteration 3
# Processing LOS A, Departure 901, Iteration 4
# Processing LOS A, Departure 901, Iteration 5
# Processing LOS A, Departure 901, Iteration 6
# Processing LOS A, Departure 901, Iteration 7
# Processing LOS A, Departure 901, Iteration 8
# Processing LOS A, Departure 901, Iteration 9
# Processing LOS A, Departure 901, Iteration 10
# Processing LOS A, Departure 901, Iteration 11
# Processing LOS A, Departure 901, Iteration 12
# Processing LOS A, Departure 901, Iteration 13
# Processing LOS A, Departure 901, Iteration 14
# Processing LOS A, Departure 901, Iteration 15
# Processing LOS A, Departure 901, Iteration 16
# Processing LOS A, Departure 901, Iteration 17
# Processing LOS A, Departure 901, Iteration 18
# Processing LOS A, Departure 901, Iteration 19
# Processing LOS A, Departure 901, Iteration 20
# Processing LOS A, Departure 901, Iteration 21
# Processing LOS A, Departure 901, Iteration 22
# Processing LOS A, Departure 901, Iteration 23
# Processing LOS A, Departure 901, Iteration 24
# Processing LOS A, Departure 901, Iteration 25
# Processing LOS A, Departure 901, Iteration 26
# Processing LOS A, Departure 901, Iteration 27
# Processing LOS A, Departure 901, Iteration 28
# Processing LOS A, Departure 901, Iteration 29
# Processing LOS A, Departure 901, Iteration 30
# Processing LOS A, Departure 902, Iteration 1
# Processing LOS A, Departure 902, Iteration 2
# Processing LOS A, Departure 902, Iteration 3
# Processing LOS A, Departure 902, Iteration 4
# Processing LOS A, Departure 902, Iteration 5
# Processing LOS A, Departure 902, Iteration 6
# Processing LOS A, Departure 902, Iteration 7
# Processing LOS A, Departure 902, Iteration 8
# Processing LOS A, Departure 902, Iteration 9
# Processing LOS A, Departure 902, Iteration 10
# Processing LOS A, Departure 902, Iteration 11
# Processing LOS A, Departure 902, Iteration 12
# Processing LOS A, Departure 902, Iteration 13
# Processing LOS A, Departure 902, Iteration 14
# Processing LOS A, Departure 902, Iteration 15
# Processing LOS A, Departure 902, Iteration 16
# Processing LOS A, Departure 902, Iteration 17
# Processing LOS A, Departure 902, Iteration 18
# Processing LOS A, Departure 902, Iteration 19
# Processing LOS A, Departure 902, Iteration 20
# Processing LOS A, Departure 902, Iteration 21
# Processing LOS A, Departure 902, Iteration 22
# Processing LOS A, Departure 902, Iteration 23
# Processing LOS A, Departure 902, Iteration 24
# Processing LOS A, Departure 902, Iteration 25
# Processing LOS A, Departure 902, Iteration 26
# Processing LOS A, Departure 902, Iteration 27
# Processing LOS A, Departure 902, Iteration 28
# Processing LOS A, Departure 902, Iteration 29
# Processing LOS A, Departure 902, Iteration 30
# Processing LOS A, Departure 903, Iteration 1
# Processing LOS A, Departure 903, Iteration 2
# Processing LOS A, Departure 903, Iteration 3
# Processing LOS A, Departure 903, Iteration 4
# Processing LOS A, Departure 903, Iteration 5
# Processing LOS A, Departure 903, Iteration 6
# Processing LOS A, Departure 903, Iteration 7
# Processing LOS A, Departure 903, Iteration 8
# Processing LOS A, Departure 903, Iteration 9
# Processing LOS A, Departure 903, Iteration 10
# Processing LOS A, Departure 903, Iteration 11
# Processing LOS A, Departure 903, Iteration 12
# Processing LOS A, Departure 903, Iteration 13
# Processing LOS A, Departure 903, Iteration 14
# Processing LOS A, Departure 903, Iteration 15
# Processing LOS A, Departure 903, Iteration 16
# Processing LOS A, Departure 903, Iteration 17
# Processing LOS A, Departure 903, Iteration 18
# Processing LOS A, Departure 903, Iteration 19
# Processing LOS A, Departure 903, Iteration 20
# Processing LOS A, Departure 903, Iteration 21
# Processing LOS A, Departure 903, Iteration 22
# Processing LOS A, Departure 903, Iteration 23
# Processing LOS A, Departure 903, Iteration 24
# Processing LOS A, Departure 903, Iteration 25
# Processing LOS A, Departure 903, Iteration 26
# Processing LOS A, Departure 903, Iteration 27
# Processing LOS A, Departure 903, Iteration 28
# Processing LOS A, Departure 903, Iteration 29
# Processing LOS A, Departure 903, Iteration 30
# Processing LOS A, Departure 904, Iteration 1
# Processing LOS A, Departure 904, Iteration 2
# Processing LOS A, Departure 904, Iteration 3
# Processing LOS A, Departure 904, Iteration 4
# Processing LOS A, Departure 904, Iteration 5
# Processing LOS A, Departure 904, Iteration 6
# Processing LOS A, Departure 904, Iteration 7
# Processing LOS A, Departure 904, Iteration 8
# Processing LOS A, Departure 904, Iteration 9
# Processing LOS A, Departure 904, Iteration 10
# Processing LOS A, Departure 904, Iteration 11
# Processing LOS A, Departure 904, Iteration 12
# Processing LOS A, Departure 904, Iteration 13
# Processing LOS A, Departure 904, Iteration 14
# Processing LOS A, Departure 904, Iteration 15
# Processing LOS A, Departure 904, Iteration 16
# Processing LOS A, Departure 904, Iteration 17
# Processing LOS A, Departure 904, Iteration 18
# Processing LOS A, Departure 904, Iteration 19
# Processing LOS A, Departure 904, Iteration 20
# Processing LOS A, Departure 904, Iteration 21
# Processing LOS A, Departure 904, Iteration 22
# Processing LOS A, Departure 904, Iteration 23
# Processing LOS A, Departure 904, Iteration 24
# Processing LOS A, Departure 904, Iteration 25
# Processing LOS A, Departure 904, Iteration 26
# Processing LOS A, Departure 904, Iteration 27
# Processing LOS A, Departure 904, Iteration 28
# Processing LOS A, Departure 904, Iteration 29
# Processing LOS A, Departure 904, Iteration 30
# Processing LOS A, Departure 905, Iteration 1
# Processing LOS A, Departure 905, Iteration 2
# Processing LOS A, Departure 905, Iteration 3
# Processing LOS A, Departure 905, Iteration 4
# Processing LOS A, Departure 905, Iteration 5
# Processing LOS A, Departure 905, Iteration 6
# Processing LOS A, Departure 905, Iteration 7
# Processing LOS A, Departure 905, Iteration 8
# Processing LOS A, Departure 905, Iteration 9
# Processing LOS A, Departure 905, Iteration 10
# Processing LOS A, Departure 905, Iteration 11
# Processing LOS A, Departure 905, Iteration 12
# Processing LOS A, Departure 905, Iteration 13
# Processing LOS A, Departure 905, Iteration 14
# Processing LOS A, Departure 905, Iteration 15
# Processing LOS A, Departure 905, Iteration 16
# Processing LOS A, Departure 905, Iteration 17
# Processing LOS A, Departure 905, Iteration 18
# Processing LOS A, Departure 905, Iteration 19
# Processing LOS A, Departure 905, Iteration 20
# Processing LOS A, Departure 905, Iteration 21
# Processing LOS A, Departure 905, Iteration 22
# Processing LOS A, Departure 905, Iteration 23
# Processing LOS A, Departure 905, Iteration 24
# Processing LOS A, Departure 905, Iteration 25
# Processing LOS A, Departure 905, Iteration 26
# Processing LOS A, Departure 905, Iteration 27
# Processing LOS A, Departure 905, Iteration 28
# Processing LOS A, Departure 905, Iteration 29
# Processing LOS A, Departure 905, Iteration 30
# Processing LOS B, Departure 895, Iteration 1
# Processing LOS B, Departure 895, Iteration 2
# Processing LOS B, Departure 895, Iteration 3
# Processing LOS B, Departure 895, Iteration 4
# Processing LOS B, Departure 895, Iteration 5
# Processing LOS B, Departure 895, Iteration 6
# Processing LOS B, Departure 895, Iteration 7
# Processing LOS B, Departure 895, Iteration 8
# Processing LOS B, Departure 895, Iteration 9
# Processing LOS B, Departure 895, Iteration 10
# Processing LOS B, Departure 895, Iteration 11
# Processing LOS B, Departure 895, Iteration 12
# Processing LOS B, Departure 895, Iteration 13
# Processing LOS B, Departure 895, Iteration 14
# Processing LOS B, Departure 895, Iteration 15
# Processing LOS B, Departure 895, Iteration 16
# Processing LOS B, Departure 895, Iteration 17
# Processing LOS B, Departure 895, Iteration 18
# Processing LOS B, Departure 895, Iteration 19
# Processing LOS B, Departure 895, Iteration 20
# Processing LOS B, Departure 895, Iteration 21
# Processing LOS B, Departure 895, Iteration 22
# Processing LOS B, Departure 895, Iteration 23
# Processing LOS B, Departure 895, Iteration 24
# Processing LOS B, Departure 895, Iteration 25
# Processing LOS B, Departure 895, Iteration 26
# Processing LOS B, Departure 895, Iteration 27
# Processing LOS B, Departure 895, Iteration 28
# Processing LOS B, Departure 895, Iteration 29
# Processing LOS B, Departure 895, Iteration 30
# Processing LOS B, Departure 896, Iteration 1
# Processing LOS B, Departure 896, Iteration 2
# Processing LOS B, Departure 896, Iteration 3
# Processing LOS B, Departure 896, Iteration 4
# Processing LOS B, Departure 896, Iteration 5
# Processing LOS B, Departure 896, Iteration 6
# Processing LOS B, Departure 896, Iteration 7
# Processing LOS B, Departure 896, Iteration 8
# Processing LOS B, Departure 896, Iteration 9
# Processing LOS B, Departure 896, Iteration 10
# Processing LOS B, Departure 896, Iteration 11
# Processing LOS B, Departure 896, Iteration 12
# Processing LOS B, Departure 896, Iteration 13
# Processing LOS B, Departure 896, Iteration 14
# Processing LOS B, Departure 896, Iteration 15
# Processing LOS B, Departure 896, Iteration 16
# Processing LOS B, Departure 896, Iteration 17
# Processing LOS B, Departure 896, Iteration 18
# Processing LOS B, Departure 896, Iteration 19
# Processing LOS B, Departure 896, Iteration 20
# Processing LOS B, Departure 896, Iteration 21
# Processing LOS B, Departure 896, Iteration 22
# Processing LOS B, Departure 896, Iteration 23
# Processing LOS B, Departure 896, Iteration 24
# Processing LOS B, Departure 896, Iteration 25
# Processing LOS B, Departure 896, Iteration 26
# Processing LOS B, Departure 896, Iteration 27
# Processing LOS B, Departure 896, Iteration 28
# Processing LOS B, Departure 896, Iteration 29
# Processing LOS B, Departure 896, Iteration 30
# Processing LOS B, Departure 897, Iteration 1
# Processing LOS B, Departure 897, Iteration 2
# Processing LOS B, Departure 897, Iteration 3
# Processing LOS B, Departure 897, Iteration 4
# Processing LOS B, Departure 897, Iteration 5
# Processing LOS B, Departure 897, Iteration 6
# Processing LOS B, Departure 897, Iteration 7
# Processing LOS B, Departure 897, Iteration 8
# Processing LOS B, Departure 897, Iteration 9
# Processing LOS B, Departure 897, Iteration 10
# Processing LOS B, Departure 897, Iteration 11
# Processing LOS B, Departure 897, Iteration 12
# Processing LOS B, Departure 897, Iteration 13
# Processing LOS B, Departure 897, Iteration 14
# Processing LOS B, Departure 897, Iteration 15
# Processing LOS B, Departure 897, Iteration 16
# Processing LOS B, Departure 897, Iteration 17
# Processing LOS B, Departure 897, Iteration 18
# Processing LOS B, Departure 897, Iteration 19
# Processing LOS B, Departure 897, Iteration 20
# Processing LOS B, Departure 897, Iteration 21
# Processing LOS B, Departure 897, Iteration 22
# Processing LOS B, Departure 897, Iteration 23
# Processing LOS B, Departure 897, Iteration 24
# Processing LOS B, Departure 897, Iteration 25
# Processing LOS B, Departure 897, Iteration 26
# Processing LOS B, Departure 897, Iteration 27
# Processing LOS B, Departure 897, Iteration 28
# Processing LOS B, Departure 897, Iteration 29
# Processing LOS B, Departure 897, Iteration 30
# Processing LOS B, Departure 898, Iteration 1
# Processing LOS B, Departure 898, Iteration 2
# Processing LOS B, Departure 898, Iteration 3
# Processing LOS B, Departure 898, Iteration 4
# Processing LOS B, Departure 898, Iteration 5
# Processing LOS B, Departure 898, Iteration 6
# Processing LOS B, Departure 898, Iteration 7
# Processing LOS B, Departure 898, Iteration 8
# Processing LOS B, Departure 898, Iteration 9
# Processing LOS B, Departure 898, Iteration 10
# Processing LOS B, Departure 898, Iteration 11
# Processing LOS B, Departure 898, Iteration 12
# Processing LOS B, Departure 898, Iteration 13
# Processing LOS B, Departure 898, Iteration 14
# Processing LOS B, Departure 898, Iteration 15
# Processing LOS B, Departure 898, Iteration 16
# Processing LOS B, Departure 898, Iteration 17
# Processing LOS B, Departure 898, Iteration 18
# Processing LOS B, Departure 898, Iteration 19
# Processing LOS B, Departure 898, Iteration 20
# Processing LOS B, Departure 898, Iteration 21
# Processing LOS B, Departure 898, Iteration 22
# Processing LOS B, Departure 898, Iteration 23
# Processing LOS B, Departure 898, Iteration 24
# Processing LOS B, Departure 898, Iteration 25
# Processing LOS B, Departure 898, Iteration 26
# Processing LOS B, Departure 898, Iteration 27
# Processing LOS B, Departure 898, Iteration 28
# Processing LOS B, Departure 898, Iteration 29
# Processing LOS B, Departure 898, Iteration 30
# Processing LOS B, Departure 899, Iteration 1
# Processing LOS B, Departure 899, Iteration 2
# Processing LOS B, Departure 899, Iteration 3
# Processing LOS B, Departure 899, Iteration 4
# Processing LOS B, Departure 899, Iteration 5
# Processing LOS B, Departure 899, Iteration 6
# Processing LOS B, Departure 899, Iteration 7
# Processing LOS B, Departure 899, Iteration 8
# Processing LOS B, Departure 899, Iteration 9
# Processing LOS B, Departure 899, Iteration 10
# Processing LOS B, Departure 899, Iteration 11
# Processing LOS B, Departure 899, Iteration 12
# Processing LOS B, Departure 899, Iteration 13
# Processing LOS B, Departure 899, Iteration 14
# Processing LOS B, Departure 899, Iteration 15
# Processing LOS B, Departure 899, Iteration 16
# Processing LOS B, Departure 899, Iteration 17
# Processing LOS B, Departure 899, Iteration 18
# Processing LOS B, Departure 899, Iteration 19
# Processing LOS B, Departure 899, Iteration 20
# Processing LOS B, Departure 899, Iteration 21
# Processing LOS B, Departure 899, Iteration 22
# Processing LOS B, Departure 899, Iteration 23
# Processing LOS B, Departure 899, Iteration 24
# Processing LOS B, Departure 899, Iteration 25
# Processing LOS B, Departure 899, Iteration 26
# Processing LOS B, Departure 899, Iteration 27
# Processing LOS B, Departure 899, Iteration 28
# Processing LOS B, Departure 899, Iteration 29
# Processing LOS B, Departure 899, Iteration 30
# Processing LOS B, Departure 900, Iteration 1
# Processing LOS B, Departure 900, Iteration 2
# Processing LOS B, Departure 900, Iteration 3
# Processing LOS B, Departure 900, Iteration 4
# Processing LOS B, Departure 900, Iteration 5
# Processing LOS B, Departure 900, Iteration 6
# Processing LOS B, Departure 900, Iteration 7
# Processing LOS B, Departure 900, Iteration 8
# Processing LOS B, Departure 900, Iteration 9
# Processing LOS B, Departure 900, Iteration 10
# Processing LOS B, Departure 900, Iteration 11
# Processing LOS B, Departure 900, Iteration 12
# Processing LOS B, Departure 900, Iteration 13
# Processing LOS B, Departure 900, Iteration 14
# Processing LOS B, Departure 900, Iteration 15
# Processing LOS B, Departure 900, Iteration 16
# Processing LOS B, Departure 900, Iteration 17
# Processing LOS B, Departure 900, Iteration 18
# Processing LOS B, Departure 900, Iteration 19
# Processing LOS B, Departure 900, Iteration 20
# Processing LOS B, Departure 900, Iteration 21
# Processing LOS B, Departure 900, Iteration 22
# Processing LOS B, Departure 900, Iteration 23
# Processing LOS B, Departure 900, Iteration 24
# Processing LOS B, Departure 900, Iteration 25
# Processing LOS B, Departure 900, Iteration 26
# Processing LOS B, Departure 900, Iteration 27
# Processing LOS B, Departure 900, Iteration 28
# Processing LOS B, Departure 900, Iteration 29
# Processing LOS B, Departure 900, Iteration 30
# Processing LOS B, Departure 901, Iteration 1
# Processing LOS B, Departure 901, Iteration 2
# Processing LOS B, Departure 901, Iteration 3
# Processing LOS B, Departure 901, Iteration 4
# Processing LOS B, Departure 901, Iteration 5
# Processing LOS B, Departure 901, Iteration 6
# Processing LOS B, Departure 901, Iteration 7
# Processing LOS B, Departure 901, Iteration 8
# Processing LOS B, Departure 901, Iteration 9
# Processing LOS B, Departure 901, Iteration 10
# Processing LOS B, Departure 901, Iteration 11
# Processing LOS B, Departure 901, Iteration 12
# Processing LOS B, Departure 901, Iteration 13
# Processing LOS B, Departure 901, Iteration 14
# Processing LOS B, Departure 901, Iteration 15
# Processing LOS B, Departure 901, Iteration 16
# Processing LOS B, Departure 901, Iteration 17
# Processing LOS B, Departure 901, Iteration 18
# Processing LOS B, Departure 901, Iteration 19
# Processing LOS B, Departure 901, Iteration 20
# Processing LOS B, Departure 901, Iteration 21
# Processing LOS B, Departure 901, Iteration 22
# Processing LOS B, Departure 901, Iteration 23
# Processing LOS B, Departure 901, Iteration 24
# Processing LOS B, Departure 901, Iteration 25
# Processing LOS B, Departure 901, Iteration 26
# Processing LOS B, Departure 901, Iteration 27
# Processing LOS B, Departure 901, Iteration 28
# Processing LOS B, Departure 901, Iteration 29
# Processing LOS B, Departure 901, Iteration 30
# Processing LOS B, Departure 902, Iteration 1
# Processing LOS B, Departure 902, Iteration 2
# Processing LOS B, Departure 902, Iteration 3
# Processing LOS B, Departure 902, Iteration 4
# Processing LOS B, Departure 902, Iteration 5
# Processing LOS B, Departure 902, Iteration 6
# Processing LOS B, Departure 902, Iteration 7
# Processing LOS B, Departure 902, Iteration 8
# Processing LOS B, Departure 902, Iteration 9
# Processing LOS B, Departure 902, Iteration 10
# Processing LOS B, Departure 902, Iteration 11
# Processing LOS B, Departure 902, Iteration 12
# Processing LOS B, Departure 902, Iteration 13
# Processing LOS B, Departure 902, Iteration 14
# Processing LOS B, Departure 902, Iteration 15
# Processing LOS B, Departure 902, Iteration 16
# Processing LOS B, Departure 902, Iteration 17
# Processing LOS B, Departure 902, Iteration 18
# Processing LOS B, Departure 902, Iteration 19
# Processing LOS B, Departure 902, Iteration 20
# Processing LOS B, Departure 902, Iteration 21
# Processing LOS B, Departure 902, Iteration 22
# Processing LOS B, Departure 902, Iteration 23
# Processing LOS B, Departure 902, Iteration 24
# Processing LOS B, Departure 902, Iteration 25
# Processing LOS B, Departure 902, Iteration 26
# Processing LOS B, Departure 902, Iteration 27
# Processing LOS B, Departure 902, Iteration 28
# Processing LOS B, Departure 902, Iteration 29
# Processing LOS B, Departure 902, Iteration 30
# Processing LOS B, Departure 903, Iteration 1
# Processing LOS B, Departure 903, Iteration 2
# Processing LOS B, Departure 903, Iteration 3
# Processing LOS B, Departure 903, Iteration 4
# Processing LOS B, Departure 903, Iteration 5
# Processing LOS B, Departure 903, Iteration 6
# Processing LOS B, Departure 903, Iteration 7
# Processing LOS B, Departure 903, Iteration 8
# Processing LOS B, Departure 903, Iteration 9
# Processing LOS B, Departure 903, Iteration 10
# Processing LOS B, Departure 903, Iteration 11
# Processing LOS B, Departure 903, Iteration 12
# Processing LOS B, Departure 903, Iteration 13
# Processing LOS B, Departure 903, Iteration 14
# Processing LOS B, Departure 903, Iteration 15
# Processing LOS B, Departure 903, Iteration 16
# Processing LOS B, Departure 903, Iteration 17
# Processing LOS B, Departure 903, Iteration 18
# Processing LOS B, Departure 903, Iteration 19
# Processing LOS B, Departure 903, Iteration 20
# Processing LOS B, Departure 903, Iteration 21
# Processing LOS B, Departure 903, Iteration 22
# Processing LOS B, Departure 903, Iteration 23
# Processing LOS B, Departure 903, Iteration 24
# Processing LOS B, Departure 903, Iteration 25
# Processing LOS B, Departure 903, Iteration 26
# Processing LOS B, Departure 903, Iteration 27
# Processing LOS B, Departure 903, Iteration 28
# Processing LOS B, Departure 903, Iteration 29
# Processing LOS B, Departure 903, Iteration 30
# Processing LOS B, Departure 904, Iteration 1
# Processing LOS B, Departure 904, Iteration 2
# Processing LOS B, Departure 904, Iteration 3
# Processing LOS B, Departure 904, Iteration 4
# Processing LOS B, Departure 904, Iteration 5
# Processing LOS B, Departure 904, Iteration 6
# Processing LOS B, Departure 904, Iteration 7
# Processing LOS B, Departure 904, Iteration 8
# Processing LOS B, Departure 904, Iteration 9
# Processing LOS B, Departure 904, Iteration 10
# Processing LOS B, Departure 904, Iteration 11
# Processing LOS B, Departure 904, Iteration 12
# Processing LOS B, Departure 904, Iteration 13
# Processing LOS B, Departure 904, Iteration 14
# Processing LOS B, Departure 904, Iteration 15
# Processing LOS B, Departure 904, Iteration 16
# Processing LOS B, Departure 904, Iteration 17
# Processing LOS B, Departure 904, Iteration 18
# Processing LOS B, Departure 904, Iteration 19
# Processing LOS B, Departure 904, Iteration 20
# Processing LOS B, Departure 904, Iteration 21
# Processing LOS B, Departure 904, Iteration 22
# Processing LOS B, Departure 904, Iteration 23
# Processing LOS B, Departure 904, Iteration 24
# Processing LOS B, Departure 904, Iteration 25
# Processing LOS B, Departure 904, Iteration 26
# Processing LOS B, Departure 904, Iteration 27
# Processing LOS B, Departure 904, Iteration 28
# Processing LOS B, Departure 904, Iteration 29
# Processing LOS B, Departure 904, Iteration 30
# Processing LOS B, Departure 905, Iteration 1
# Processing LOS B, Departure 905, Iteration 2
# Processing LOS B, Departure 905, Iteration 3
# Processing LOS B, Departure 905, Iteration 4
# Processing LOS B, Departure 905, Iteration 5
# Processing LOS B, Departure 905, Iteration 6
# Processing LOS B, Departure 905, Iteration 7
# Processing LOS B, Departure 905, Iteration 8
# Processing LOS B, Departure 905, Iteration 9
# Processing LOS B, Departure 905, Iteration 10
# Processing LOS B, Departure 905, Iteration 11
# Processing LOS B, Departure 905, Iteration 12
# Processing LOS B, Departure 905, Iteration 13
# Processing LOS B, Departure 905, Iteration 14
# Processing LOS B, Departure 905, Iteration 15
# Processing LOS B, Departure 905, Iteration 16
# Processing LOS B, Departure 905, Iteration 17
# Processing LOS B, Departure 905, Iteration 18
# Processing LOS B, Departure 905, Iteration 19
# Processing LOS B, Departure 905, Iteration 20
# Processing LOS B, Departure 905, Iteration 21
# Processing LOS B, Departure 905, Iteration 22
# Processing LOS B, Departure 905, Iteration 23
# Processing LOS B, Departure 905, Iteration 24
# Processing LOS B, Departure 905, Iteration 25
# Processing LOS B, Departure 905, Iteration 26
# Processing LOS B, Departure 905, Iteration 27
# Processing LOS B, Departure 905, Iteration 28
# Processing LOS B, Departure 905, Iteration 29
# Processing LOS B, Departure 905, Iteration 30
# Processing LOS C, Departure 895, Iteration 1
# Processing LOS C, Departure 895, Iteration 2
# Processing LOS C, Departure 895, Iteration 3
# Processing LOS C, Departure 895, Iteration 4
# Processing LOS C, Departure 895, Iteration 5
# Processing LOS C, Departure 895, Iteration 6
# Processing LOS C, Departure 895, Iteration 7
# Processing LOS C, Departure 895, Iteration 8
# Processing LOS C, Departure 895, Iteration 9
# Processing LOS C, Departure 895, Iteration 10
# Processing LOS C, Departure 895, Iteration 11
# Processing LOS C, Departure 895, Iteration 12
# Processing LOS C, Departure 895, Iteration 13
# Processing LOS C, Departure 895, Iteration 14
# Processing LOS C, Departure 895, Iteration 15
# Processing LOS C, Departure 895, Iteration 16
# Processing LOS C, Departure 895, Iteration 17
# Processing LOS C, Departure 895, Iteration 18
# Processing LOS C, Departure 895, Iteration 19
# Processing LOS C, Departure 895, Iteration 20
# Processing LOS C, Departure 895, Iteration 21
# Processing LOS C, Departure 895, Iteration 22
# Processing LOS C, Departure 895, Iteration 23
# Processing LOS C, Departure 895, Iteration 24
# Processing LOS C, Departure 895, Iteration 25
# Processing LOS C, Departure 895, Iteration 26
# Processing LOS C, Departure 895, Iteration 27
# Processing LOS C, Departure 895, Iteration 28
# Processing LOS C, Departure 895, Iteration 29
# Processing LOS C, Departure 895, Iteration 30
# Processing LOS C, Departure 896, Iteration 1
# Processing LOS C, Departure 896, Iteration 2
# Processing LOS C, Departure 896, Iteration 3
# Processing LOS C, Departure 896, Iteration 4
# Processing LOS C, Departure 896, Iteration 5
# Processing LOS C, Departure 896, Iteration 6
# Processing LOS C, Departure 896, Iteration 7
# Processing LOS C, Departure 896, Iteration 8
# Processing LOS C, Departure 896, Iteration 9
# Processing LOS C, Departure 896, Iteration 10
# Processing LOS C, Departure 896, Iteration 11
# Processing LOS C, Departure 896, Iteration 12
# Processing LOS C, Departure 896, Iteration 13
# Processing LOS C, Departure 896, Iteration 14
# Processing LOS C, Departure 896, Iteration 15
# Processing LOS C, Departure 896, Iteration 16
# Processing LOS C, Departure 896, Iteration 17
# Processing LOS C, Departure 896, Iteration 18
# Processing LOS C, Departure 896, Iteration 19
# Processing LOS C, Departure 896, Iteration 20
# Processing LOS C, Departure 896, Iteration 21
# Processing LOS C, Departure 896, Iteration 22
# Processing LOS C, Departure 896, Iteration 23
# Processing LOS C, Departure 896, Iteration 24
# Processing LOS C, Departure 896, Iteration 25
# Processing LOS C, Departure 896, Iteration 26
# Processing LOS C, Departure 896, Iteration 27
# Processing LOS C, Departure 896, Iteration 28
# Processing LOS C, Departure 896, Iteration 29
# Processing LOS C, Departure 896, Iteration 30
# Processing LOS C, Departure 897, Iteration 1
# Processing LOS C, Departure 897, Iteration 2
# Processing LOS C, Departure 897, Iteration 3
# Processing LOS C, Departure 897, Iteration 4
# Processing LOS C, Departure 897, Iteration 5
# Processing LOS C, Departure 897, Iteration 6
# Processing LOS C, Departure 897, Iteration 7
# Processing LOS C, Departure 897, Iteration 8
# Processing LOS C, Departure 897, Iteration 9
# Processing LOS C, Departure 897, Iteration 10
# Processing LOS C, Departure 897, Iteration 11
# Processing LOS C, Departure 897, Iteration 12
# Processing LOS C, Departure 897, Iteration 13
# Processing LOS C, Departure 897, Iteration 14
# Processing LOS C, Departure 897, Iteration 15
# Processing LOS C, Departure 897, Iteration 16
# Processing LOS C, Departure 897, Iteration 17
# Processing LOS C, Departure 897, Iteration 18
# Processing LOS C, Departure 897, Iteration 19
# Processing LOS C, Departure 897, Iteration 20
# Processing LOS C, Departure 897, Iteration 21
# Processing LOS C, Departure 897, Iteration 22
# Processing LOS C, Departure 897, Iteration 23
# Processing LOS C, Departure 897, Iteration 24
# Processing LOS C, Departure 897, Iteration 25
# Processing LOS C, Departure 897, Iteration 26
# Processing LOS C, Departure 897, Iteration 27
# Processing LOS C, Departure 897, Iteration 28
# Processing LOS C, Departure 897, Iteration 29
# Processing LOS C, Departure 897, Iteration 30
# Processing LOS C, Departure 898, Iteration 1
# Processing LOS C, Departure 898, Iteration 2
# Processing LOS C, Departure 898, Iteration 3
# Processing LOS C, Departure 898, Iteration 4
# Processing LOS C, Departure 898, Iteration 5
# Processing LOS C, Departure 898, Iteration 6
# Processing LOS C, Departure 898, Iteration 7
# Processing LOS C, Departure 898, Iteration 8
# Processing LOS C, Departure 898, Iteration 9
# Processing LOS C, Departure 898, Iteration 10
# Processing LOS C, Departure 898, Iteration 11
# Processing LOS C, Departure 898, Iteration 12
# Processing LOS C, Departure 898, Iteration 13
# Processing LOS C, Departure 898, Iteration 14
# Processing LOS C, Departure 898, Iteration 15
# Processing LOS C, Departure 898, Iteration 16
# Processing LOS C, Departure 898, Iteration 17
# Processing LOS C, Departure 898, Iteration 18
# Processing LOS C, Departure 898, Iteration 19
# Processing LOS C, Departure 898, Iteration 20
# Processing LOS C, Departure 898, Iteration 21
# Processing LOS C, Departure 898, Iteration 22
# Processing LOS C, Departure 898, Iteration 23
# Processing LOS C, Departure 898, Iteration 24
# Processing LOS C, Departure 898, Iteration 25
# Processing LOS C, Departure 898, Iteration 26
# Processing LOS C, Departure 898, Iteration 27
# Processing LOS C, Departure 898, Iteration 28
# Processing LOS C, Departure 898, Iteration 29
# Processing LOS C, Departure 898, Iteration 30
# Processing LOS C, Departure 899, Iteration 1
# Processing LOS C, Departure 899, Iteration 2
# Processing LOS C, Departure 899, Iteration 3
# Processing LOS C, Departure 899, Iteration 4
# Processing LOS C, Departure 899, Iteration 5
# Processing LOS C, Departure 899, Iteration 6
# Processing LOS C, Departure 899, Iteration 7
# Processing LOS C, Departure 899, Iteration 8
# Processing LOS C, Departure 899, Iteration 9
# Processing LOS C, Departure 899, Iteration 10
# Processing LOS C, Departure 899, Iteration 11
# Processing LOS C, Departure 899, Iteration 12
# Processing LOS C, Departure 899, Iteration 13
# Processing LOS C, Departure 899, Iteration 14
# Processing LOS C, Departure 899, Iteration 15
# Processing LOS C, Departure 899, Iteration 16
# Processing LOS C, Departure 899, Iteration 17
# Processing LOS C, Departure 899, Iteration 18
# Processing LOS C, Departure 899, Iteration 19
# Processing LOS C, Departure 899, Iteration 20
# Processing LOS C, Departure 899, Iteration 21
# Processing LOS C, Departure 899, Iteration 22
# Processing LOS C, Departure 899, Iteration 23
# Processing LOS C, Departure 899, Iteration 24
# Processing LOS C, Departure 899, Iteration 25
# Processing LOS C, Departure 899, Iteration 26
# Processing LOS C, Departure 899, Iteration 27
# Processing LOS C, Departure 899, Iteration 28
# Processing LOS C, Departure 899, Iteration 29
# Processing LOS C, Departure 899, Iteration 30
# Processing LOS C, Departure 900, Iteration 1
# Processing LOS C, Departure 900, Iteration 2
# Processing LOS C, Departure 900, Iteration 3
# Processing LOS C, Departure 900, Iteration 4
# Processing LOS C, Departure 900, Iteration 5
# Processing LOS C, Departure 900, Iteration 6
# Processing LOS C, Departure 900, Iteration 7
# Processing LOS C, Departure 900, Iteration 8
# Processing LOS C, Departure 900, Iteration 9
# Processing LOS C, Departure 900, Iteration 10
# Processing LOS C, Departure 900, Iteration 11
# Processing LOS C, Departure 900, Iteration 12
# Processing LOS C, Departure 900, Iteration 13
# Processing LOS C, Departure 900, Iteration 14
# Processing LOS C, Departure 900, Iteration 15
# Processing LOS C, Departure 900, Iteration 16
# Processing LOS C, Departure 900, Iteration 17
# Processing LOS C, Departure 900, Iteration 18
# Processing LOS C, Departure 900, Iteration 19
# Processing LOS C, Departure 900, Iteration 20
# Processing LOS C, Departure 900, Iteration 21
# Processing LOS C, Departure 900, Iteration 22
# Processing LOS C, Departure 900, Iteration 23
# Processing LOS C, Departure 900, Iteration 24
# Processing LOS C, Departure 900, Iteration 25
# Processing LOS C, Departure 900, Iteration 26
# Processing LOS C, Departure 900, Iteration 27
# Processing LOS C, Departure 900, Iteration 28
# Processing LOS C, Departure 900, Iteration 29
# Processing LOS C, Departure 900, Iteration 30
# Processing LOS C, Departure 901, Iteration 1
# Processing LOS C, Departure 901, Iteration 2
# Processing LOS C, Departure 901, Iteration 3
# Processing LOS C, Departure 901, Iteration 4
# Processing LOS C, Departure 901, Iteration 5
# Processing LOS C, Departure 901, Iteration 6
# Processing LOS C, Departure 901, Iteration 7
# Processing LOS C, Departure 901, Iteration 8
# Processing LOS C, Departure 901, Iteration 9
# Processing LOS C, Departure 901, Iteration 10
# Processing LOS C, Departure 901, Iteration 11
# Processing LOS C, Departure 901, Iteration 12
# Processing LOS C, Departure 901, Iteration 13
# Processing LOS C, Departure 901, Iteration 14
# Processing LOS C, Departure 901, Iteration 15
# Processing LOS C, Departure 901, Iteration 16
# Processing LOS C, Departure 901, Iteration 17
# Processing LOS C, Departure 901, Iteration 18
# Processing LOS C, Departure 901, Iteration 19
# Processing LOS C, Departure 901, Iteration 20
# Processing LOS C, Departure 901, Iteration 21
# Processing LOS C, Departure 901, Iteration 22
# Processing LOS C, Departure 901, Iteration 23
# Processing LOS C, Departure 901, Iteration 24
# Processing LOS C, Departure 901, Iteration 25
# Processing LOS C, Departure 901, Iteration 26
# Processing LOS C, Departure 901, Iteration 27
# Processing LOS C, Departure 901, Iteration 28
# Processing LOS C, Departure 901, Iteration 29
# Processing LOS C, Departure 901, Iteration 30
# Processing LOS C, Departure 902, Iteration 1
# Processing LOS C, Departure 902, Iteration 2
# Processing LOS C, Departure 902, Iteration 3
# Processing LOS C, Departure 902, Iteration 4
# Processing LOS C, Departure 902, Iteration 5
# Processing LOS C, Departure 902, Iteration 6
# Processing LOS C, Departure 902, Iteration 7
# Processing LOS C, Departure 902, Iteration 8
# Processing LOS C, Departure 902, Iteration 9
# Processing LOS C, Departure 902, Iteration 10
# Processing LOS C, Departure 902, Iteration 11
# Processing LOS C, Departure 902, Iteration 12
# Processing LOS C, Departure 902, Iteration 13
# Processing LOS C, Departure 902, Iteration 14
# Processing LOS C, Departure 902, Iteration 15
# Processing LOS C, Departure 902, Iteration 16
# Processing LOS C, Departure 902, Iteration 17
# Processing LOS C, Departure 902, Iteration 18
# Processing LOS C, Departure 902, Iteration 19
# Processing LOS C, Departure 902, Iteration 20
# Processing LOS C, Departure 902, Iteration 21
# Processing LOS C, Departure 902, Iteration 22
# Processing LOS C, Departure 902, Iteration 23
# Processing LOS C, Departure 902, Iteration 24
# Processing LOS C, Departure 902, Iteration 25
# Processing LOS C, Departure 902, Iteration 26
# Processing LOS C, Departure 902, Iteration 27
# Processing LOS C, Departure 902, Iteration 28
# Processing LOS C, Departure 902, Iteration 29
# Processing LOS C, Departure 902, Iteration 30
# Processing LOS C, Departure 903, Iteration 1
# Processing LOS C, Departure 903, Iteration 2
# Processing LOS C, Departure 903, Iteration 3
# Processing LOS C, Departure 903, Iteration 4
# Processing LOS C, Departure 903, Iteration 5
# Processing LOS C, Departure 903, Iteration 6
# Processing LOS C, Departure 903, Iteration 7
# Processing LOS C, Departure 903, Iteration 8
# Processing LOS C, Departure 903, Iteration 9
# Processing LOS C, Departure 903, Iteration 10
# Processing LOS C, Departure 903, Iteration 11
# Processing LOS C, Departure 903, Iteration 12
# Processing LOS C, Departure 903, Iteration 13
# Processing LOS C, Departure 903, Iteration 14
# Processing LOS C, Departure 903, Iteration 15
# Processing LOS C, Departure 903, Iteration 16
# Processing LOS C, Departure 903, Iteration 17
# Processing LOS C, Departure 903, Iteration 18
# Processing LOS C, Departure 903, Iteration 19
# Processing LOS C, Departure 903, Iteration 20
# Processing LOS C, Departure 903, Iteration 21
# Processing LOS C, Departure 903, Iteration 22
# Processing LOS C, Departure 903, Iteration 23
# Processing LOS C, Departure 903, Iteration 24
# Processing LOS C, Departure 903, Iteration 25
# Processing LOS C, Departure 903, Iteration 26
# Processing LOS C, Departure 903, Iteration 27
# Processing LOS C, Departure 903, Iteration 28
# Processing LOS C, Departure 903, Iteration 29
# Processing LOS C, Departure 903, Iteration 30
# Processing LOS C, Departure 904, Iteration 1
# Processing LOS C, Departure 904, Iteration 2
# Processing LOS C, Departure 904, Iteration 3
# Processing LOS C, Departure 904, Iteration 4
# Processing LOS C, Departure 904, Iteration 5
# Processing LOS C, Departure 904, Iteration 6
# Processing LOS C, Departure 904, Iteration 7
# Processing LOS C, Departure 904, Iteration 8
# Processing LOS C, Departure 904, Iteration 9
# Processing LOS C, Departure 904, Iteration 10
# Processing LOS C, Departure 904, Iteration 11
# Processing LOS C, Departure 904, Iteration 12
# Processing LOS C, Departure 904, Iteration 13
# Processing LOS C, Departure 904, Iteration 14
# Processing LOS C, Departure 904, Iteration 15
# Processing LOS C, Departure 904, Iteration 16
# Processing LOS C, Departure 904, Iteration 17
# Processing LOS C, Departure 904, Iteration 18
# Processing LOS C, Departure 904, Iteration 19
# Processing LOS C, Departure 904, Iteration 20
# Processing LOS C, Departure 904, Iteration 21
# Processing LOS C, Departure 904, Iteration 22
# Processing LOS C, Departure 904, Iteration 23
# Processing LOS C, Departure 904, Iteration 24
# Processing LOS C, Departure 904, Iteration 25
# Processing LOS C, Departure 904, Iteration 26
# Processing LOS C, Departure 904, Iteration 27
# Processing LOS C, Departure 904, Iteration 28
# Processing LOS C, Departure 904, Iteration 29
# Processing LOS C, Departure 904, Iteration 30
# Processing LOS C, Departure 905, Iteration 1
# Processing LOS C, Departure 905, Iteration 2
# Processing LOS C, Departure 905, Iteration 3
# Processing LOS C, Departure 905, Iteration 4
# Processing LOS C, Departure 905, Iteration 5
# Processing LOS C, Departure 905, Iteration 6
# Processing LOS C, Departure 905, Iteration 7
# Processing LOS C, Departure 905, Iteration 8
# Processing LOS C, Departure 905, Iteration 9
# Processing LOS C, Departure 905, Iteration 10
# Processing LOS C, Departure 905, Iteration 11
# Processing LOS C, Departure 905, Iteration 12
# Processing LOS C, Departure 905, Iteration 13
# Processing LOS C, Departure 905, Iteration 14
# Processing LOS C, Departure 905, Iteration 15
# Processing LOS C, Departure 905, Iteration 16
# Processing LOS C, Departure 905, Iteration 17
# Processing LOS C, Departure 905, Iteration 18
# Processing LOS C, Departure 905, Iteration 19
# Processing LOS C, Departure 905, Iteration 20
# Processing LOS C, Departure 905, Iteration 21
# Processing LOS C, Departure 905, Iteration 22
# Processing LOS C, Departure 905, Iteration 23
# Processing LOS C, Departure 905, Iteration 24
# Processing LOS C, Departure 905, Iteration 25
# Processing LOS C, Departure 905, Iteration 26
# Processing LOS C, Departure 905, Iteration 27
# Processing LOS C, Departure 905, Iteration 28
# Processing LOS C, Departure 905, Iteration 29
# Processing LOS C, Departure 905, Iteration 30
# Processing LOS D, Departure 895, Iteration 1
# Processing LOS D, Departure 895, Iteration 2
# Processing LOS D, Departure 895, Iteration 3
# Processing LOS D, Departure 895, Iteration 4
# Processing LOS D, Departure 895, Iteration 5
# Processing LOS D, Departure 895, Iteration 6
# Processing LOS D, Departure 895, Iteration 7
# Processing LOS D, Departure 895, Iteration 8
# Processing LOS D, Departure 895, Iteration 9
# Processing LOS D, Departure 895, Iteration 10
# Processing LOS D, Departure 895, Iteration 11
# Processing LOS D, Departure 895, Iteration 12
# Processing LOS D, Departure 895, Iteration 13
# Processing LOS D, Departure 895, Iteration 14
# Processing LOS D, Departure 895, Iteration 15
# Processing LOS D, Departure 895, Iteration 16
# Processing LOS D, Departure 895, Iteration 17
# Processing LOS D, Departure 895, Iteration 18
# Processing LOS D, Departure 895, Iteration 19
# Processing LOS D, Departure 895, Iteration 20
# Processing LOS D, Departure 895, Iteration 21
# Processing LOS D, Departure 895, Iteration 22
# Processing LOS D, Departure 895, Iteration 23
# Processing LOS D, Departure 895, Iteration 24
# Processing LOS D, Departure 895, Iteration 25
# Processing LOS D, Departure 895, Iteration 26
# Processing LOS D, Departure 895, Iteration 27
# Processing LOS D, Departure 895, Iteration 28
# Processing LOS D, Departure 895, Iteration 29
# Processing LOS D, Departure 895, Iteration 30
# Processing LOS D, Departure 896, Iteration 1
# Processing LOS D, Departure 896, Iteration 2
# Processing LOS D, Departure 896, Iteration 3
# Processing LOS D, Departure 896, Iteration 4
# Processing LOS D, Departure 896, Iteration 5
# Processing LOS D, Departure 896, Iteration 6
# Processing LOS D, Departure 896, Iteration 7
# Processing LOS D, Departure 896, Iteration 8
# Processing LOS D, Departure 896, Iteration 9
# Processing LOS D, Departure 896, Iteration 10
# Processing LOS D, Departure 896, Iteration 11
# Processing LOS D, Departure 896, Iteration 12
# Processing LOS D, Departure 896, Iteration 13
# Processing LOS D, Departure 896, Iteration 14
# Processing LOS D, Departure 896, Iteration 15
# Processing LOS D, Departure 896, Iteration 16
# Processing LOS D, Departure 896, Iteration 17
# Processing LOS D, Departure 896, Iteration 18
# Processing LOS D, Departure 896, Iteration 19
# Processing LOS D, Departure 896, Iteration 20
# Processing LOS D, Departure 896, Iteration 21
# Processing LOS D, Departure 896, Iteration 22
# Processing LOS D, Departure 896, Iteration 23
# Processing LOS D, Departure 896, Iteration 24
# ...
# Processing LOS E, Departure 895, Iteration 1
# Processing LOS E, Departure 895, Iteration 2
# Processing LOS E, Departure 895, Iteration 3
# Processing LOS E, Departure 895, Iteration 4
# Processing LOS E, Departure 895, Iteration 5
# Processing LOS E, Departure 895, Iteration 6
# Processing LOS E, Departure 895, Iteration 7
# Processing LOS E, Departure 895, Iteration 8
# Processing LOS E, Departure 895, Iteration 9
# Processing LOS E, Departure 895, Iteration 10
# Processing LOS E, Departure 895, Iteration 11
# Processing LOS E, Departure 895, Iteration 12
# Processing LOS E, Departure 895, Iteration 13
# Processing LOS E, Departure 895, Iteration 14
# Processing LOS E, Departure 895, Iteration 15
# Processing LOS E, Departure 895, Iteration 16
# Processing LOS E, Departure 895, Iteration 17
# Processing LOS E, Departure 895, Iteration 18
# Processing LOS E, Departure 895, Iteration 19
# Processing LOS E, Departure 895, Iteration 20
# Processing LOS E, Departure 895, Iteration 21
# Processing LOS E, Departure 895, Iteration 22
# Processing LOS E, Departure 895, Iteration 23
# Processing LOS E, Departure 895, Iteration 24
# Processing LOS E, Departure 895, Iteration 25
# Processing LOS E, Departure 895, Iteration 26
# Processing LOS E, Departure 895, Iteration 27
# Processing LOS E, Departure 895, Iteration 28
# Processing LOS E, Departure 895, Iteration 29
# Processing LOS E, Departure 895, Iteration 30
# Processing LOS E, Departure 896, Iteration 1
# Processing LOS E, Departure 896, Iteration 2
# Processing LOS E, Departure 896, Iteration 3
# Processing LOS E, Departure 896, Iteration 4
# Processing LOS E, Departure 896, Iteration 5
# Processing LOS E, Departure 896, Iteration 6
# Processing LOS E, Departure 896, Iteration 7
# Processing LOS E, Departure 896, Iteration 8
# Processing LOS E, Departure 896, Iteration 9
# Processing LOS E, Departure 896, Iteration 10
# Processing LOS E, Departure 896, Iteration 11
# Processing LOS E, Departure 896, Iteration 12
# Processing LOS E, Departure 896, Iteration 13
# Processing LOS E, Departure 896, Iteration 14
# Processing LOS E, Departure 896, Iteration 15
# Processing LOS E, Departure 896, Iteration 16
# Processing LOS E, Departure 896, Iteration 17
# Processing LOS E, Departure 896, Iteration 18
# Processing LOS E, Departure 896, Iteration 19
# Processing LOS E, Departure 896, Iteration 20
# Processing LOS E, Departure 896, Iteration 21
# Processing LOS E, Departure 896, Iteration 22
# Processing LOS E, Departure 896, Iteration 23
# Processing LOS E, Departure 896, Iteration 24
# Processing LOS E, Departure 896, Iteration 25
# Processing LOS E, Departure 896, Iteration 26
# Processing LOS E, Departure 896, Iteration 27
# Processing LOS E, Departure 896, Iteration 28
# Processing LOS E, Departure 896, Iteration 29
# Processing LOS E, Departure 896, Iteration 30
# Processing LOS E, Departure 897, Iteration 1
# Processing LOS E, Departure 897, Iteration 2
# Processing LOS E, Departure 897, Iteration 3
# Processing LOS E, Departure 897, Iteration 4
# Processing LOS E, Departure 897, Iteration 5
# Processing LOS E, Departure 897, Iteration 6
# Processing LOS E, Departure 897, Iteration 7
# Processing LOS E, Departure 897, Iteration 8
# Processing LOS E, Departure 897, Iteration 9
# Processing LOS E, Departure 897, Iteration 10
# Processing LOS E, Departure 897, Iteration 11
# Processing LOS E, Departure 897, Iteration 12
# Processing LOS E, Departure 897, Iteration 13
# Processing LOS E, Departure 897, Iteration 14
# Processing LOS E, Departure 897, Iteration 15
# Processing LOS E, Departure 897, Iteration 16
# Processing LOS E, Departure 897, Iteration 17
# Processing LOS E, Departure 897, Iteration 18
# Processing LOS E, Departure 897, Iteration 19
# Processing LOS E, Departure 897, Iteration 20
# Processing LOS E, Departure 897, Iteration 21
# Processing LOS E, Departure 897, Iteration 22
# Processing LOS E, Departure 897, Iteration 23
# Processing LOS E, Departure 897, Iteration 24
# Processing LOS E, Departure 897, Iteration 25
# Processing LOS E, Departure 897, Iteration 26
# Processing LOS E, Departure 897, Iteration 27
# Processing LOS E, Departure 897, Iteration 28
# Processing LOS E, Departure 897, Iteration 29
# Processing LOS E, Departure 897, Iteration 30
# Processing LOS E, Departure 898, Iteration 1
# Processing LOS E, Departure 898, Iteration 2
# Processing LOS E, Departure 898, Iteration 3
# Processing LOS E, Departure 898, Iteration 4
# Processing LOS E, Departure 898, Iteration 5
# Processing LOS E, Departure 898, Iteration 6
# Processing LOS E, Departure 898, Iteration 7
# Processing LOS E, Departure 898, Iteration 8
# Processing LOS E, Departure 898, Iteration 9
# Processing LOS E, Departure 898, Iteration 10
# Processing LOS E, Departure 898, Iteration 11
# Processing LOS E, Departure 898, Iteration 12
# Processing LOS E, Departure 898, Iteration 13
# Processing LOS E, Departure 898, Iteration 14
# Processing LOS E, Departure 898, Iteration 15
# Processing LOS E, Departure 898, Iteration 16
# Processing LOS E, Departure 898, Iteration 17
# Processing LOS E, Departure 898, Iteration 18
# Processing LOS E, Departure 898, Iteration 19
# Processing LOS E, Departure 898, Iteration 20
# Processing LOS E, Departure 898, Iteration 21
# Processing LOS E, Departure 898, Iteration 22
# Processing LOS E, Departure 898, Iteration 23
# Processing LOS E, Departure 898, Iteration 24
# Processing LOS E, Departure 898, Iteration 25
# Processing LOS E, Departure 898, Iteration 26
# Processing LOS E, Departure 898, Iteration 27
# Processing LOS E, Departure 898, Iteration 28
# Processing LOS E, Departure 898, Iteration 29
# Processing LOS E, Departure 898, Iteration 30
# Processing LOS E, Departure 899, Iteration 1
# Processing LOS E, Departure 899, Iteration 2
# Processing LOS E, Departure 899, Iteration 3
# Processing LOS E, Departure 899, Iteration 4
# Processing LOS E, Departure 899, Iteration 5
# Processing LOS E, Departure 899, Iteration 6
# Processing LOS E, Departure 899, Iteration 7
# Processing LOS E, Departure 899, Iteration 8
# Processing LOS E, Departure 899, Iteration 9
# Processing LOS E, Departure 899, Iteration 10
# Processing LOS E, Departure 899, Iteration 11
# Processing LOS E, Departure 899, Iteration 12
# Processing LOS E, Departure 899, Iteration 13
# Processing LOS E, Departure 899, Iteration 14
# Processing LOS E, Departure 899, Iteration 15
# Processing LOS E, Departure 899, Iteration 16
# Processing LOS E, Departure 899, Iteration 17
# Processing LOS E, Departure 899, Iteration 18
# Processing LOS E, Departure 899, Iteration 19
# Processing LOS E, Departure 899, Iteration 20
# Processing LOS E, Departure 899, Iteration 21
# Processing LOS E, Departure 899, Iteration 22
# Processing LOS E, Departure 899, Iteration 23
# Processing LOS E, Departure 899, Iteration 24
# Processing LOS E, Departure 899, Iteration 25
# Processing LOS E, Departure 899, Iteration 26
# Processing LOS E, Departure 899, Iteration 27
# Processing LOS E, Departure 899, Iteration 28
# Processing LOS E, Departure 899, Iteration 29
# Processing LOS E, Departure 899, Iteration 30
# Processing LOS E, Departure 900, Iteration 1
# Processing LOS E, Departure 900, Iteration 2
# Processing LOS E, Departure 900, Iteration 3
# Processing LOS E, Departure 900, Iteration 4
# Processing LOS E, Departure 900, Iteration 5
# Processing LOS E, Departure 900, Iteration 6
# Processing LOS E, Departure 900, Iteration 7
# Processing LOS E, Departure 900, Iteration 8
# Processing LOS E, Departure 900, Iteration 9
# Processing LOS E, Departure 900, Iteration 10
# Processing LOS E, Departure 900, Iteration 11
# Processing LOS E, Departure 900, Iteration 12
# Processing LOS E, Departure 900, Iteration 13
# Processing LOS E, Departure 900, Iteration 14
# Processing LOS E, Departure 900, Iteration 15
# Processing LOS E, Departure 900, Iteration 16
# Processing LOS E, Departure 900, Iteration 17
# Processing LOS E, Departure 900, Iteration 18
# Processing LOS E, Departure 900, Iteration 19
# Processing LOS E, Departure 900, Iteration 20
# Processing LOS E, Departure 900, Iteration 21
# Processing LOS E, Departure 900, Iteration 22
# Processing LOS E, Departure 900, Iteration 23
# Processing LOS E, Departure 900, Iteration 24
# Processing LOS E, Departure 900, Iteration 25
# Processing LOS E, Departure 900, Iteration 26
# Processing LOS E, Departure 900, Iteration 27
# Processing LOS E, Departure 900, Iteration 28
# Processing LOS E, Departure 900, Iteration 29
# Processing LOS E, Departure 900, Iteration 30
# Processing LOS E, Departure 901, Iteration 1
# Processing LOS E, Departure 901, Iteration 2
# Processing LOS E, Departure 901, Iteration 3
# Processing LOS E, Departure 901, Iteration 4
# Processing LOS E, Departure 901, Iteration 5
# Processing LOS E, Departure 901, Iteration 6
# Processing LOS E, Departure 901, Iteration 7
# Processing LOS E, Departure 901, Iteration 8
# Processing LOS E, Departure 901, Iteration 9
# Processing LOS E, Departure 901, Iteration 10
# Processing LOS E, Departure 901, Iteration 11
# Processing LOS E, Departure 901, Iteration 12
# Processing LOS E, Departure 901, Iteration 13
# Processing LOS E, Departure 901, Iteration 14
# Processing LOS E, Departure 901, Iteration 15
# Processing LOS E, Departure 901, Iteration 16
# Processing LOS E, Departure 901, Iteration 17
# Processing LOS E, Departure 901, Iteration 18
# Processing LOS E, Departure 901, Iteration 19
# Processing LOS E, Departure 901, Iteration 20
# Processing LOS E, Departure 901, Iteration 21
# Processing LOS E, Departure 901, Iteration 22
# Processing LOS E, Departure 901, Iteration 23
# Processing LOS E, Departure 901, Iteration 24
# Processing LOS E, Departure 901, Iteration 25
# Processing LOS E, Departure 901, Iteration 26
# Processing LOS E, Departure 901, Iteration 27
# Processing LOS E, Departure 901, Iteration 28
# Processing LOS E, Departure 901, Iteration 29
# Processing LOS E, Departure 901, Iteration 30
# Processing LOS E, Departure 902, Iteration 1
# Processing LOS E, Departure 902, Iteration 2
# Processing LOS E, Departure 902, Iteration 3
# Processing LOS E, Departure 902, Iteration 4
# Processing LOS E, Departure 902, Iteration 5
# Processing LOS E, Departure 902, Iteration 6
# Processing LOS E, Departure 902, Iteration 7
# Processing LOS E, Departure 902, Iteration 8
# Processing LOS E, Departure 902, Iteration 9
# Processing LOS E, Departure 902, Iteration 10
# Processing LOS E, Departure 902, Iteration 11
# Processing LOS E, Departure 902, Iteration 12
# Processing LOS E, Departure 902, Iteration 13
# Processing LOS E, Departure 902, Iteration 14
# Processing LOS E, Departure 902, Iteration 15
# Processing LOS E, Departure 902, Iteration 16
# Processing LOS E, Departure 902, Iteration 17
# Processing LOS E, Departure 902, Iteration 18
# Processing LOS E, Departure 902, Iteration 19
# Processing LOS E, Departure 902, Iteration 20
# Processing LOS E, Departure 902, Iteration 21
# Processing LOS E, Departure 902, Iteration 22
# Processing LOS E, Departure 902, Iteration 23
# Processing LOS E, Departure 902, Iteration 24
# Processing LOS E, Departure 902, Iteration 25
# Processing LOS E, Departure 902, Iteration 26
# Processing LOS E, Departure 902, Iteration 27
# Processing LOS E, Departure 902, Iteration 28
# Processing LOS E, Departure 902, Iteration 29
# Processing LOS E, Departure 902, Iteration 30
# Processing LOS E, Departure 903, Iteration 1
# Processing LOS E, Departure 903, Iteration 2
# Processing LOS E, Departure 903, Iteration 3
# Processing LOS E, Departure 903, Iteration 4
# Processing LOS E, Departure 903, Iteration 5
# Processing LOS E, Departure 903, Iteration 6
# Processing LOS E, Departure 903, Iteration 7
# Processing LOS E, Departure 903, Iteration 8
# Processing LOS E, Departure 903, Iteration 9
# Processing LOS E, Departure 903, Iteration 10
# Processing LOS E, Departure 903, Iteration 11
# Processing LOS E, Departure 903, Iteration 12
# Processing LOS E, Departure 903, Iteration 13
# Processing LOS E, Departure 903, Iteration 14
# Processing LOS E, Departure 903, Iteration 15
# Processing LOS E, Departure 903, Iteration 16
# Processing LOS E, Departure 903, Iteration 17
# Processing LOS E, Departure 903, Iteration 18
# Processing LOS E, Departure 903, Iteration 19
# Processing LOS E, Departure 903, Iteration 20
# Processing LOS E, Departure 903, Iteration 21
# Processing LOS E, Departure 903, Iteration 22
# Processing LOS E, Departure 903, Iteration 23
# Processing LOS E, Departure 903, Iteration 24
# Processing LOS E, Departure 903, Iteration 25
# Processing LOS E, Departure 903, Iteration 26
# Processing LOS E, Departure 903, Iteration 27
# Processing LOS E, Departure 903, Iteration 28
# Processing LOS E, Departure 903, Iteration 29
# Processing LOS E, Departure 903, Iteration 30
# Processing LOS E, Departure 904, Iteration 1
# Processing LOS E, Departure 904, Iteration 2
# Processing LOS E, Departure 904, Iteration 3
# Processing LOS E, Departure 904, Iteration 4
# Processing LOS E, Departure 904, Iteration 5
# Processing LOS E, Departure 904, Iteration 6
# Processing LOS E, Departure 904, Iteration 7
# Processing LOS E, Departure 904, Iteration 8
# Processing LOS E, Departure 904, Iteration 9
# Processing LOS E, Departure 904, Iteration 10
# Processing LOS E, Departure 904, Iteration 11
# Processing LOS E, Departure 904, Iteration 12
# Processing LOS E, Departure 904, Iteration 13
# Processing LOS E, Departure 904, Iteration 14
# Processing LOS E, Departure 904, Iteration 15
# Processing LOS E, Departure 904, Iteration 16
# Processing LOS E, Departure 904, Iteration 17
# Processing LOS E, Departure 904, Iteration 18
# Processing LOS E, Departure 904, Iteration 19
# Processing LOS E, Departure 904, Iteration 20
# Processing LOS E, Departure 904, Iteration 21
# Processing LOS E, Departure 904, Iteration 22
# Processing LOS E, Departure 904, Iteration 23
# Processing LOS E, Departure 904, Iteration 24
# Processing LOS E, Departure 904, Iteration 25
# Processing LOS E, Departure 904, Iteration 26
# Processing LOS E, Departure 904, Iteration 27
# Processing LOS E, Departure 904, Iteration 28
# Processing LOS E, Departure 904, Iteration 29
# Processing LOS E, Departure 904, Iteration 30
# Processing LOS E, Departure 905, Iteration 1
# Processing LOS E, Departure 905, Iteration 2
# Processing LOS E, Departure 905, Iteration 3
# Processing LOS E, Departure 905, Iteration 4
# Processing LOS E, Departure 905, Iteration 5
# Processing LOS E, Departure 905, Iteration 6
# Processing LOS E, Departure 905, Iteration 7
# Processing LOS E, Departure 905, Iteration 8
# Processing LOS E, Departure 905, Iteration 9
# Processing LOS E, Departure 905, Iteration 10
# Processing LOS E, Departure 905, Iteration 11
# Processing LOS E, Departure 905, Iteration 12
# Processing LOS E, Departure 905, Iteration 13
# Processing LOS E, Departure 905, Iteration 14
# Processing LOS E, Departure 905, Iteration 15
# Processing LOS E, Departure 905, Iteration 16
# Processing LOS E, Departure 905, Iteration 17
# Processing LOS E, Departure 905, Iteration 18
# Processing LOS E, Departure 905, Iteration 19
# Processing LOS E, Departure 905, Iteration 20
# Processing LOS E, Departure 905, Iteration 21
# Processing LOS E, Departure 905, Iteration 22
# Processing LOS E, Departure 905, Iteration 23
# Processing LOS E, Departure 905, Iteration 24
# Processing LOS E, Departure 905, Iteration 25
# Processing LOS E, Departure 905, Iteration 26
# Processing LOS E, Departure 905, Iteration 27
# Processing LOS E, Departure 905, Iteration 28
# Processing LOS E, Departure 905, Iteration 29
# Processing LOS E, Departure 905, Iteration 30
# Top 10 global parameter combinations (across all sequences):
#                a  window_size  loss_func        PD       FAR  Youden_index
# 38  2.000000e-01           15        mse  0.912430  0.184784      0.727646
# 43  3.000000e-01           15        mse  0.902059  0.174698      0.727361
# 48  4.000000e-01           15        mse  0.890466  0.163353      0.727113
# 33  1.000000e-01           15        mse  0.920942  0.194086      0.726856
# 28 -1.110223e-16           15        mse  0.928544  0.202304      0.726240
# 23 -1.000000e-01           15        mse  0.934310  0.208984      0.725326
# 18 -2.000000e-01           15        mse  0.938310  0.214767      0.723543
# 35  2.000000e-01           15  hausdorff  0.901920  0.179775      0.722146
# 39  2.000000e-01           15       rmse  0.901920  0.179775      0.722146
# 37  2.000000e-01           15        mae  0.901920  0.179775      0.722146

# %%
top100 = agg_results.sort_values(by='Youden_index', ascending=False).head(20)

print("\nTop 10 global parameter combinations (across all sequences):")
print(top100)
# Out:
# Top 10 global parameter combinations (across all sequences):
#                a  window_size  loss_func        PD       FAR  Youden_index
# 38  2.000000e-01           15        mse  0.912430  0.184784      0.727646
# 43  3.000000e-01           15        mse  0.902059  0.174698      0.727361
# 48  4.000000e-01           15        mse  0.890466  0.163353      0.727113
# 33  1.000000e-01           15        mse  0.920942  0.194086      0.726856
# 28 -1.110223e-16           15        mse  0.928544  0.202304      0.726240
# 23 -1.000000e-01           15        mse  0.934310  0.208984      0.725326
# 18 -2.000000e-01           15        mse  0.938310  0.214767      0.723543
# 35  2.000000e-01           15  hausdorff  0.901920  0.179775      0.722146
# 39  2.000000e-01           15       rmse  0.901920  0.179775      0.722146
# 37  2.000000e-01           15        mae  0.901920  0.179775      0.722146
# 45  4.000000e-01           15  hausdorff  0.886683  0.164704      0.721979
# 47  4.000000e-01           15        mae  0.886683  0.164704      0.721979
# 49  4.000000e-01           15       rmse  0.886683  0.164704      0.721979
# 27 -1.110223e-16           15        mae  0.914304  0.192341      0.721963
# 29 -1.110223e-16           15       rmse  0.914304  0.192341      0.721963
# 25 -1.110223e-16           15  hausdorff  0.914304  0.192341      0.721963
# 42  3.000000e-01           15        mae  0.895382  0.173445      0.721937
# 44  3.000000e-01           15       rmse  0.895382  0.173445      0.721937
# 40  3.000000e-01           15  hausdorff  0.895382  0.173445      0.721937
# 30  1.000000e-01           15  hausdorff  0.908054  0.186676      0.721378

# %%
# Re-import required libraries after environment reset
import pandas as pd
import numpy as np

# Save the top 20 combinations to a CSV file
top100 = agg_results.sort_values(by='Youden_index', ascending=False)
top100.to_csv("top_20_global_parameter_combinations.csv", index=False)

top100
# Out:
#                a  window_size  loss_func        PD       FAR  Youden_index
# 38  2.000000e-01           15        mse  0.912430  0.184784      0.727646
# 43  3.000000e-01           15        mse  0.902059  0.174698      0.727361
# 48  4.000000e-01           15        mse  0.890466  0.163353      0.727113
# 33  1.000000e-01           15        mse  0.920942  0.194086      0.726856
# 28 -1.110223e-16           15        mse  0.928544  0.202304      0.726240
# 23 -1.000000e-01           15        mse  0.934310  0.208984      0.725326
# 18 -2.000000e-01           15        mse  0.938310  0.214767      0.723543
# 35  2.000000e-01           15  hausdorff  0.901920  0.179775      0.722146
# 39  2.000000e-01           15       rmse  0.901920  0.179775      0.722146
# 37  2.000000e-01           15        mae  0.901920  0.179775      0.722146
# 45  4.000000e-01           15  hausdorff  0.886683  0.164704      0.721979
# 47  4.000000e-01           15        mae  0.886683  0.164704      0.721979
# 49  4.000000e-01           15       rmse  0.886683  0.164704      0.721979
# 27 -1.110223e-16           15        mae  0.914304  0.192341      0.721963
# 29 -1.110223e-16           15       rmse  0.914304  0.192341      0.721963
# 25 -1.110223e-16           15  hausdorff  0.914304  0.192341      0.721963
# 42  3.000000e-01           15        mae  0.895382  0.173445      0.721937
# 44  3.000000e-01           15       rmse  0.895382  0.173445      0.721937
# 40  3.000000e-01           15  hausdorff  0.895382  0.173445      0.721937
# 30  1.000000e-01           15  hausdorff  0.908054  0.186676      0.721378
# 34  1.000000e-01           15       rmse  0.908054  0.186676      0.721378
# 32  1.000000e-01           15        mae  0.908054  0.186676      0.721378
# 22 -1.000000e-01           15        mae  0.918753  0.197940      0.720812
# 24 -1.000000e-01           15       rmse  0.918753  0.197940      0.720812
# 20 -1.000000e-01           15  hausdorff  0.918753  0.197940      0.720812
# 17 -2.000000e-01           15        mae  0.923082  0.202780      0.720302
# 15 -2.000000e-01           15  hausdorff  0.923082  0.202780      0.720302
# 19 -2.000000e-01           15       rmse  0.923082  0.202780      0.720302
# 13 -3.000000e-01           15        mse  0.945794  0.266182      0.679611
# 14 -3.000000e-01           15       rmse  0.930177  0.251100      0.679077
# 10 -3.000000e-01           15  hausdorff  0.930177  0.251100      0.679077
# 12 -3.000000e-01           15        mae  0.930177  0.251100      0.679077
# 8  -4.000000e-01           15        mse  0.955257  0.350365      0.604892
# 7  -4.000000e-01           15        mae  0.945746  0.351038      0.594708
# 5  -4.000000e-01           15  hausdorff  0.945746  0.351038      0.594708
# 9  -4.000000e-01           15       rmse  0.945746  0.351038      0.594708
# 0  -5.000000e-01           15  hausdorff  0.958671  0.487217      0.471453
# 4  -5.000000e-01           15       rmse  0.958671  0.487217      0.471453
# 2  -5.000000e-01           15        mae  0.958671  0.487217      0.471453
# 3  -5.000000e-01           15        mse  0.965748  0.495466      0.470282
# 21 -1.000000e-01           15      huber  0.355046  0.057235      0.297811
# 16 -2.000000e-01           15      huber  0.356373  0.059066      0.297307
# 26 -1.110223e-16           15      huber  0.354180  0.056959      0.297221
# 31  1.000000e-01           15      huber  0.353401  0.056700      0.296701
# 36  2.000000e-01           15      huber  0.349909  0.056370      0.293539
# 41  3.000000e-01           15      huber  0.347080  0.055881      0.291199
# 11 -3.000000e-01           15      huber  0.403835  0.114582      0.289253
# 46  4.000000e-01           15      huber  0.342636  0.055171      0.287465
# 6  -4.000000e-01           15      huber  0.494619  0.272996      0.221623
# 1  -5.000000e-01           15      huber  0.565102  0.479506      0.085596

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

def plot_pd_vs_far_with_optimal_point(agg_results):
    plt.figure(figsize=(8, 6))
    
    # Scatter plot
    scatter = plt.scatter(
        agg_results['FAR'], agg_results['PD'],
        c=agg_results['Youden_index'], cmap='viridis', s=80, edgecolor='k'
    )
    plt.colorbar(scatter, label='Youden Index')

    # Add diagonal reference line (line of no discrimination)
    x = np.linspace(0, 1, 100)
    plt.plot(x, x, color='gray', linestyle='--', label='No Discrimination Line (PD=FAR)')

    # Compute perpendicular distance from each point to the line y = x
    distances = np.abs(agg_results['PD'] - agg_results['FAR']) / np.sqrt(2)
    max_idx = distances.idxmax()
    optimal_row = agg_results.loc[max_idx]

    # Plot the optimal point and its perpendicular line to the diagonal
    optimal_far = optimal_row['FAR']
    optimal_pd = optimal_row['PD']
    plt.plot([optimal_far, optimal_pd], [optimal_pd, optimal_far], 'r--', label='Max Perpendicular Distance')
    plt.scatter(optimal_far, optimal_pd, color='red', s=100, zorder=5, label=f"Optimal (a={np.round(optimal_row['a'],3)})")

    # Labels and grid
    plt.xlabel('False Alarm Rate (FAR)')
    plt.ylabel('Probability of Detection (PD)')
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()


plot_pd_vs_far_with_optimal_point(agg_results)
